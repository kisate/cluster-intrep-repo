# %%
import os
os.chdir("..")

# %%
from cluster_intrep_repo.utils import DOMAIN_PHRASES

# %%
mapping = {
    "actions": {
        "attack": "pick up",
        "succumb": "put down",
        "overcome": "stack",
        "feast": "unstack"
    },
    "predicates": {
        
    }
}
