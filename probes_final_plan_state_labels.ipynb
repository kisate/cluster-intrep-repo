# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

# %%
os.chdir("..")

# %%
import torch
import numpy as np
from transformers import AutoTokenizer
from transformers import AutoModelForCausalLM
from tqdm.auto import tqdm
from datasets import load_dataset
from cluster_intrep_repo.utils import initialize_tokenizer, tokenize_blocksworld_generation, THINK_TOKEN



os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"

compute_dtype = torch.bfloat16
device   = 'cuda'
model_id = "deepseek-ai/DeepSeek-R1-Distill-Qwen-32B"

# %%
tokenizer = initialize_tokenizer(model_id)

# %%
blocksworld_type = "4-blocks"

dataset = load_dataset(f"dmitriihook/deepseek-r1-qwen-32b-planning-{blocksworld_type}")["train"]

# %%
labels_dataset = load_dataset(f"dmitriihook/blocksworld-4-final-labels")["train"]
# Out:
# blocksworld-4-final-labels.json:   0%|          | 0.00/416k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1500 [00:00<?, ? examples/s]

# %%
model     = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=compute_dtype, attn_implementation="sdpa", device_map="auto")
# Out:
# Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
n_rows = 1500

# %%
from collections import defaultdict

# [src; dest]

layer_hidden_states = defaultdict(list)

n_last_layers = 10

for row in tqdm(dataset.select(range(n_rows))):
    generation = row["generation"]

    if "</think>" not in generation:
        for j in range(n_last_layers):
            layer_hidden_states[j].append(None) 
        continue

    chat = tokenize_blocksworld_generation(tokenizer, row)

    # think_pos = torch.where(chat.squeeze() == THINK_TOKEN)[0]

    with torch.no_grad():
        outputs = model(chat.to(device), output_hidden_states=True)

        for j in range(n_last_layers):
            hidden_states = outputs.hidden_states[-1 - j]
            layer_hidden_states[j].append(hidden_states[0].to(torch.float16).cpu().numpy())
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]

# %%
for j in range(n_last_layers):
    # layer_hidden_states[j] = [x for x in layer_hidden_states[j] if x is not None]
    print(len(layer_hidden_states[j]))
# Out:
# 1500
# 1500
# 1500
# 1500
# 1500
# 1500
# 1500
# 1500
# 1500
# 1500

# %%
import re
from collections import defaultdict

def parse_blocks(text):
    initial_state = []
    goal_state = []
    
    # Extract the initial conditions and goal state
    initial_match = re.search(r'As initial conditions I have that:(.*?)My goal is for the following to be true:', text, re.DOTALL)
    goal_match = re.search(r'My goal is for the following to be true:(.*?)\n\n', text, re.DOTALL)

    if initial_match:
        initial_conditions = re.findall(r'Block [A-Z] is on top of Block [A-Z]', initial_match.group(1))
        init_table_blocks = re.findall(r'Block ([A-Z]) is on the table', initial_match.group(1))
        initial_state = process_conditions(initial_conditions)

    
    if goal_match:
        goal_conditions = re.findall(r'Block [A-Z] is on top of Block [A-Z]', goal_match.group(1))
        goal_table_blocks = re.findall(r'Block ([A-Z]) is on the table', goal_match.group(1))
        goal_state = process_conditions(goal_conditions)

    
    return (initial_state, init_table_blocks), (goal_state, goal_table_blocks)

def process_conditions(conditions):
    pairs = {}
    
    for cond in conditions:
        block, below = re.findall(r'Block ([A-Z])', cond)
        pairs[block] = below
    
    return pairs


item = dataset[2]["query"]
stmt = item.split("[STATEMENT]")[-1].strip()

initial_state, goal_state = parse_blocks(stmt)
initial_state, goal_state
# Out:
# (({'B': 'C', 'C': 'D'}, ['A', 'D']), ({'A': 'C', 'C': 'D', 'D': 'B'}, []))

# %%
def state_to_pairs(state, all_blocks):
    pairs, _ = state
    below = {}

    for block, below_block in pairs.items():
        below[block] = below_block

    for block in all_blocks:
        if block not in below:
            below[block] = "table"

    above = {}

    for block, below_block in below.items():
        if below_block != "table":
            above[below_block] = block

    for block in all_blocks:
        if block not in above:
            above[block] = "sky"
    
    return above, below

# %%
def collect_all_blocks(initial_state):
    all_blocks = list(initial_state[0].keys())
    all_blocks.extend(initial_state[1])
    all_blocks.extend(initial_state[0].values())
    return list(set(all_blocks))

# %%
all_blocks = collect_all_blocks(initial_state)

state_to_pairs(initial_state, all_blocks)
# Out:
# ({'C': 'B', 'D': 'C', 'A': 'sky', 'B': 'sky'},
#  {'B': 'C', 'C': 'D', 'A': 'table', 'D': 'table'})

# %%
from typing import Optional

def apply_action(action: list[str], state: tuple[dict, dict, Optional[str]]) -> Optional[tuple[dict, dict, Optional[str]]]: 
    above, below, hand = state
    # print(action)

    above = above.copy()
    below = below.copy()

    action_type, blocks = action[0], action[1:]

    if action_type == "pick up":
        if hand is not None:
            return None
        block = blocks[0]
        above_block = above[block]

        if above_block != "sky":
            return None
        
        below_block = below[block]
        if below_block != "table":
            above[below_block] = "sky"
            below[block] = "table"
        
        hand = block

    elif action_type == "put down":
        if hand is None:
            return None
        
        if hand != blocks[0]:
            return None
        
        block = blocks[0]
        hand = None
    elif action_type == "unstack":
        if hand is not None:
            return None
        
        block1, block2 = blocks
        if above[block1] != "sky":
            return None
        if below[block1] != block2:
            return None
        
        above[block2] = "sky"
        below[block1] = "table"

        hand = block1
    elif action_type == "stack":
        block1, block2 = blocks

        if hand != block1:
            return None

        if above[block2] != "sky":
            return None
        
        above[block2] = block1
        below[block1] = block2
        hand = None

    return above, below, hand

# %%
def find_index_before_block(text):
    text = text.lower()
    regex = r"\d+\.\s*(?:unstack|put down|pick up|stack)\s+(?:block\s+)?([a-z])"

    match = re.search(regex, text)
    
    return match.start(1) if match else None

training_data = []
for label_item in tqdm(labels_dataset.select(range(n_rows))):
    i = label_item["index"]
    if label_item["label"] is None:
        continue

    row = dataset[i]
    actions = label_item["label"]["final_plan"]
    # print(actions)
    generation: str = row["generation"]

    if "</think>" not in generation:
        continue

    head, tail = generation.split("</think>")
    phrase = label_item["label"]["starting_phrase"]

    phrase_end = head.rfind(phrase)

    text = head[:phrase_end + len(phrase)]
    _text = head[phrase_end + len(phrase):]
    block_idx = find_index_before_block(_text)

    if block_idx is None:
        continue

    text += _text[:block_idx]

    group = []

    stmt = row["query"].split("[STATEMENT]")[-1].strip()
    initial_state, goal_state = parse_blocks(stmt)

    all_blocks = collect_all_blocks(initial_state)
    initial_state = state_to_pairs(initial_state, all_blocks)
    goal_state = state_to_pairs(goal_state, all_blocks)

    current_state = (initial_state[0], initial_state[1], None)

    group = []

    for action in actions:
        if current_state is None:
            continue

        try:
            next_state = apply_action(action, current_state)
        except Exception as e:
            print(e)
            next_state = None
        if next_state is not None:
            group.append({
                "idx": i,
                "action": action,
                "before_state": current_state,
                "after_state": next_state
            })

        current_state = next_state
    
    tokens = tokenize_blocksworld_generation(tokenizer, row, text)[0]


    training_data.append({
        "idx": i,
        "initial_state": initial_state,
        "goal_state": goal_state,
        "actions": actions,
        "group": group,
        "pos": len(tokens),
        "phrase": phrase
    })
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]
# 'the table'
# 'table'
# 'table'
# not enough values to unpack (expected 2, got 1)
# 'table'

# %%
item = training_data[11]

row = dataset[item["idx"]]

tokens = tokenize_blocksworld_generation(tokenizer, row)[0]

tokenizer.decode(tokens[item["pos"]:item["pos"]+5])
# Out:
# ' C. (D is'

# %%
training_data[0]
# Out:
# {'idx': 0,
#  'initial_state': ({'A': 'B', 'D': 'C', 'B': 'sky', 'C': 'sky'},
#   {'B': 'A', 'C': 'D', 'A': 'table', 'D': 'table'}),
#  'goal_state': ({'D': 'A', 'C': 'B', 'B': 'D', 'A': 'sky'},
#   {'A': 'D', 'B': 'C', 'D': 'B', 'C': 'table'}),
#  'actions': [['unstack', 'C', 'D'],
#   ['put down', 'C'],
#   ['unstack', 'B', 'A'],
#   ['stack', 'B', 'C'],
#   ['pick up', 'D'],
#   ['stack', 'D', 'B'],
#   ['pick up', 'A'],
#   ['stack', 'A', 'D']],
#  'group': [{'idx': 0,
#    'action': ['unstack', 'C', 'D'],
#    'before_state': ({'A': 'B', 'D': 'C', 'B': 'sky', 'C': 'sky'},
#     {'B': 'A', 'C': 'D', 'A': 'table', 'D': 'table'},
#     None),
#    'after_state': ({'A': 'B', 'D': 'sky', 'B': 'sky', 'C': 'sky'},
#     {'B': 'A', 'C': 'table', 'A': 'table', 'D': 'table'},
#     'C')},
#   {'idx': 0,
#    'action': ['put down', 'C'],
#    'before_state': ({'A': 'B', 'D': 'sky', 'B': 'sky', 'C': 'sky'},
#     {'B': 'A', 'C': 'table', 'A': 'table', 'D': 'table'},
#     'C'),
#    'after_state': ({'A': 'B', 'D': 'sky', 'B': 'sky', 'C': 'sky'},
#     {'B': 'A', 'C': 'table', 'A': 'table', 'D': 'table'},
#     None)},
#   {'idx': 0,
#    'action': ['unstack', 'B', 'A'],
#    'before_state': ({'A': 'B', 'D': 'sky', 'B': 'sky', 'C': 'sky'},
#     {'B': 'A', 'C': 'table', 'A': 'table', 'D': 'table'},
#     None),
#    'after_state': ({'A': 'sky', 'D': 'sky', 'B': 'sky', 'C': 'sky'},
#     {'B': 'table', 'C': 'table', 'A': 'table', 'D': 'table'},
#     'B')},
#   {'idx': 0,
#    'action': ['stack', 'B', 'C'],
#    'before_state': ({'A': 'sky', 'D': 'sky', 'B': 'sky', 'C': 'sky'},
#     {'B': 'table', 'C': 'table', 'A': 'table', 'D': 'table'},
#     'B'),
#    'after_state': ({'A': 'sky', 'D': 'sky', 'B': 'sky', 'C': 'B'},
#     {'B': 'C', 'C': 'table', 'A': 'table', 'D': 'table'},
#     None)},
#   {'idx': 0,
#    'action': ['pick up', 'D'],
#    'before_state': ({'A': 'sky', 'D': 'sky', 'B': 'sky', 'C': 'B'},
#     {'B': 'C', 'C': 'table', 'A': 'table', 'D': 'table'},
#     None),
#    'after_state': ({'A': 'sky', 'D': 'sky', 'B': 'sky', 'C': 'B'},
#     {'B': 'C', 'C': 'table', 'A': 'table', 'D': 'table'},
#     'D')},
#   {'idx': 0,
#    'action': ['stack', 'D', 'B'],
#    'before_state': ({'A': 'sky', 'D': 'sky', 'B': 'sky', 'C': 'B'},
#     {'B': 'C', 'C': 'table', 'A': 'table', 'D': 'table'},
#     'D'),
#    'after_state': ({'A': 'sky', 'D': 'sky', 'B': 'D', 'C': 'B'},
#     {'B': 'C', 'C': 'table', 'A': 'table', 'D': 'B'},
#     None)},
#   {'idx': 0,
#    'action': ['pick up', 'A'],
#    'before_state': ({'A': 'sky', 'D': 'sky', 'B': 'D', 'C': 'B'},
#     {'B': 'C', 'C': 'table', 'A': 'table', 'D': 'B'},
#     None),
#    'after_state': ({'A': 'sky', 'D': 'sky', 'B': 'D', 'C': 'B'},
#     {'B': 'C', 'C': 'table', 'A': 'table', 'D': 'B'},
#     'A')},
#   {'idx': 0,
#    'action': ['stack', 'A', 'D'],
#    'before_state': ({'A': 'sky', 'D': 'sky', 'B': 'D', 'C': 'B'},
#     {'B': 'C', 'C': 'table', 'A': 'table', 'D': 'B'},
#     'A'),
#    'after_state': ({'A': 'sky', 'D': 'A', 'B': 'D', 'C': 'B'},
#     {'B': 'C', 'C': 'table', 'A': 'D', 'D': 'B'},
#     None)}],
#  'pos': 4610,
#  'phrase': 'Let me try to outline the desired final stack: A on D on B on C. So the order from bottom to top is C, B, D, A.'}

# %%
n_blocks = int(dataset[n_rows - 1]["instance_id"].split("_")[0])
n_blocks
# Out:
# 4

# %%
from torch.utils.data import Dataset

act2int = {
    "put down": 0,
    "pick up": 1,
    "stack": 2,
    "unstack": 3
}

def block2int(block):
    if block == "table":
        return n_blocks
    if block == "sky":
        return n_blocks + 1
    
    return ord(block) - ord("A")

def int2block(i):
    if i == n_blocks:
        return "table"
    if i == n_blocks + 1:
        return "sky"
    
    return chr(i + ord("A"))

n_prev_tokens = 10

def state_to_label(state):
    above, below, hand = state
    label = np.zeros((n_blocks * 2, ), dtype=np.int64)

    for block, below_block in below.items():
        label[block2int(block)] = block2int(below_block)
    for block, above_block in above.items():
        label[block2int(block) + n_blocks] = block2int(above_block)

    return label



class StepProbeDataset(Dataset):
    def __init__(self, items, hidden_states, n_layer, jump):
        self.items = items
        self.hidden_states = hidden_states
        self.n_layer = n_layer
        self.jump = jump

    def __len__(self):
        return len(self.items)
    
    def __getitem__(self, idx):
        item = self.items[idx]
        hidden_states = self.hidden_states[self.n_layer][item["idx"]]
        pos = item["pos"]

        above, below, hand = item["group"][self.jump]["after_state"]

        return {
            "input": hidden_states[pos:pos+20],
            "labels": state_to_label((above, below, hand))
        }

# %%
import random

def make_training_data(jump=0, train_test_split=0.9):
    # expanded_training_data = []

    # for group in training_data:
    #     group = group["group"]
    #     for action1, action2 in zip(group, group[jump:]):
    #         if len(action1["action"][1]) < 1:
    #             continue
    #         expanded_training_data.append((action1, action2))
    #         # continue

    filtered_data = [x for x in training_data if len(x["group"]) > jump]
    filtered_data = [x for x in filtered_data if layer_hidden_states[0][x["idx"]] is not None]

    random.shuffle(filtered_data)

    n_train = int(len(filtered_data) * train_test_split)

    train_items = filtered_data[:n_train]
    test_items = filtered_data[n_train:]

    train_dataset = StepProbeDataset(train_items, layer_hidden_states, 0, jump=jump)
    test_dataset = StepProbeDataset(test_items, layer_hidden_states, 0, jump=jump)

    return train_dataset, test_dataset

# %%
class StepProbe(torch.nn.Module):
    def __init__(self, input_size, hidden_size, n_blocks):
        super().__init__()
        # self.fc = torch.nn.Linear(input_size, hidden_size)
        # self.fc2 = torch.nn.Linear(hidden_size, n_blocks * (n_blocks + 2) * 2)
        self.fc2 = torch.nn.Linear(input_size, n_blocks * (n_blocks + 2) * 2)
        # self.dropout = torch.nn.Dropout(0.1)
        
    def forward(self, x):
        # x = self.fc(x)
        # x = torch.nn.functional.relu(x)
        # x = self.dropout(x)
        x = self.fc2(x[:, 0])
        return x.view(-1, n_blocks + 2, n_blocks * 2)

# %%
class GRUProbe(torch.nn.Module):
    def __init__(self, input_size, hidden_size, n_blocks):
        super().__init__()
        self.gru = torch.nn.GRU(input_size, hidden_size, batch_first=True)
        self.fc = torch.nn.Linear(hidden_size, n_blocks * (n_blocks + 2) * 2)
        
    def forward(self, x):
        x /= 2
        x, _ = self.gru(x)
        x = x[:, -1]
        x = self.fc(x)
        return x.view(-1, n_blocks + 2, n_blocks * 2)

# %%
jumps = list(range(6))

jump_datasets = {
    jump: make_training_data(jump) for jump in jumps
}

for jump, (train, test) in jump_datasets.items():
    print(jump, len(train), len(test))
# Out:
# 0 1221 136
# 1 1189 133
# 2 1168 130
# 3 1147 128
# 4 1098 122
# 5 1079 120

# %%
n_dim = 5120

probes = {jump: StepProbe(n_dim, 500, n_blocks).to(device) for jump in jumps}

# %%
import torch
import numpy as np
from torch.optim import AdamW
from torch.utils.data import DataLoader
from torch.nn import CrossEntropyLoss
from sklearn.metrics import f1_score

def train_probe(probe, train_dataset, test_dataset, patience=100):
    optimizer = AdamW(probe.parameters(), lr=1e-3, weight_decay=1e-2)
    criterion = CrossEntropyLoss(weight=torch.tensor([1.0] * n_blocks + [0.1] * 2).to(device))
    train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)

    n_epochs = 500
    best_f1 = float('inf')
    early_stop_counter = 0
    
    for epoch in range(n_epochs):
        probe.train()
        total_loss = 0
        n_samples = 0

        for batch in train_loader:
            optimizer.zero_grad()
            input = batch["input"].to(device).float()
            labels = batch["labels"].to(device)
            
            output = probe(input)

            loss = criterion(output, labels)
            
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item() * len(batch["input"])
            n_samples += len(batch["input"])

        avg_train_loss = total_loss / n_samples
        
        # Evaluation
        probe.eval()
        with torch.no_grad():
            block_wise_hits = np.zeros((n_blocks * 2), dtype=np.int64)
            total = 0  
            val_loss = 0
            all_preds = []
            all_labels = []
            
            for batch in test_loader:
                input = batch["input"].to(device).float()
                labels = batch["labels"].to(device)
                
                output = probe(input)

                loss = criterion(output, labels)
                val_loss += loss.item() * len(batch["input"])

                preds = output.argmax(dim=-2)  # Assuming classification task
                hits = (preds == labels)
                
                block_wise_hits += hits.sum(dim=0).cpu().numpy()
                total += len(labels)
                
                all_preds.append(preds.cpu().numpy())
                all_labels.append(labels.cpu().numpy())
            
            block_wise_hits = block_wise_hits / total
            
            all_preds = np.concatenate(all_preds)
            all_labels = np.concatenate(all_labels)
            
            # Compute F1 score block-wise
            block_wise_f1 = np.zeros(n_blocks * 2)
            for i in range(n_blocks * 2):
                block_wise_f1[i] = f1_score(all_labels[:, i], all_preds[:, i], average='macro')
            
            avg_f1 = block_wise_f1.mean()

            val_loss /= total
            
            print(f"Epoch {epoch}, Train Loss: {avg_train_loss:.4f}, Hits: {block_wise_hits.mean():.4f}, F1: {avg_f1:.4f}, Val Loss: {val_loss:.4f}")
        
            # Early Stopping Check
            if avg_f1 > best_f1:
                best_f1 = avg_f1
                early_stop_counter = 0
            else:
                early_stop_counter += 1
            
            if early_stop_counter >= patience:
                print(f"Early stopping triggered at epoch {epoch}")
                break
    
    return block_wise_hits, block_wise_f1

# %%
for jump, (train, test) in jump_datasets.items():
    print(jump)
    print(train_probe(probes[jump], train, test))
# Out:
# 0
# Epoch 0, Train Loss: 2.5821, Hits: 0.2105, F1: 0.1392, Val Loss: 1.9838
# Epoch 1, Train Loss: 1.5632, Hits: 0.3006, F1: 0.2625, Val Loss: 1.3775
# Epoch 2, Train Loss: 1.2006, Hits: 0.3676, F1: 0.3160, Val Loss: 1.2740
# Epoch 3, Train Loss: 1.0188, Hits: 0.4513, F1: 0.3519, Val Loss: 1.2314
# Epoch 4, Train Loss: 0.9293, Hits: 0.4936, F1: 0.3989, Val Loss: 1.1498
# Epoch 5, Train Loss: 0.9133, Hits: 0.4779, F1: 0.3866, Val Loss: 1.1348
# Epoch 6, Train Loss: 0.8633, Hits: 0.5487, F1: 0.4166, Val Loss: 1.1599
# Epoch 7, Train Loss: 0.7915, Hits: 0.5625, F1: 0.4456, Val Loss: 1.0533
# Epoch 8, Train Loss: 0.7394, Hits: 0.5561, F1: 0.4295, Val Loss: 1.0291
# Epoch 92, Train Loss: 0.3652, Hits: 0.5188, F1: 0.3589, Val Loss: 1.9057
# Epoch 93, Train Loss: 0.3507, Hits: 0.5135, F1: 0.3449, Val Loss: 1.9031
# Epoch 94, Train Loss: 0.3507, Hits: 0.4906, F1: 0.3431, Val Loss: 1.9507
# Epoch 95, Train Loss: 0.3516, Hits: 0.5000, F1: 0.3405, Val Loss: 1.9442
# Epoch 96, Train Loss: 0.3456, Hits: 0.5135, F1: 0.3496, Val Loss: 1.9442
# Epoch 97, Train Loss: 0.3431, Hits: 0.4875, F1: 0.3428, Val Loss: 1.9763
# Epoch 98, Train Loss: 0.3491, Hits: 0.5083, F1: 0.3586, Val Loss: 1.9651
# Epoch 99, Train Loss: 0.3638, Hits: 0.5062, F1: 0.3488, Val Loss: 2.0111
# Early stopping triggered at epoch 99
# (array([0.58333333, 0.49166667, 0.44166667, 0.54166667, 0.45833333,
#        0.51666667, 0.49166667, 0.525     ]), array([0.41593136, 0.33323382, 0.30829625, 0.33571536, 0.32994623,
#        0.33879601, 0.3715035 , 0.35710585]))

# %%
item = training_data[-5]

# %%
item
# Out:
# {'idx': 1495,
#  'initial_state': ({'B': 'A', 'D': 'B', 'A': 'sky', 'C': 'sky'},
#   {'A': 'B', 'B': 'D', 'D': 'table', 'C': 'table'}),
#  'goal_state': ({'D': 'A', 'A': 'C', 'B': 'D', 'C': 'sky'},
#   {'A': 'D', 'C': 'A', 'D': 'B', 'B': 'table'}),
#  'actions': [['unstack', 'A', 'B'],
#   ['put down', 'A'],
#   ['unstack', 'B', 'D'],
#   ['put down', 'B'],
#   ['pick up', 'D'],
#   ['stack', 'D', 'B'],
#   ['pick up', 'A'],
#   ['stack', 'A', 'D'],
#   ['pick up', 'C'],
#   ['stack', 'C', 'A']],
#  'group': [{'idx': 1495,
#    'action': ['unstack', 'A', 'B'],
#    'before_state': ({'B': 'A', 'D': 'B', 'A': 'sky', 'C': 'sky'},
#     {'A': 'B', 'B': 'D', 'D': 'table', 'C': 'table'},
#     None),
#    'after_state': ({'B': 'sky', 'D': 'B', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'D', 'D': 'table', 'C': 'table'},
#     'A')},
#   {'idx': 1495,
#    'action': ['put down', 'A'],
#    'before_state': ({'B': 'sky', 'D': 'B', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'D', 'D': 'table', 'C': 'table'},
#     'A'),
#    'after_state': ({'B': 'sky', 'D': 'B', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'D', 'D': 'table', 'C': 'table'},
#     None)},
#   {'idx': 1495,
#    'action': ['unstack', 'B', 'D'],
#    'before_state': ({'B': 'sky', 'D': 'B', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'D', 'D': 'table', 'C': 'table'},
#     None),
#    'after_state': ({'B': 'sky', 'D': 'sky', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'table', 'D': 'table', 'C': 'table'},
#     'B')},
#   {'idx': 1495,
#    'action': ['put down', 'B'],
#    'before_state': ({'B': 'sky', 'D': 'sky', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'table', 'D': 'table', 'C': 'table'},
#     'B'),
#    'after_state': ({'B': 'sky', 'D': 'sky', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'table', 'D': 'table', 'C': 'table'},
#     None)},
#   {'idx': 1495,
#    'action': ['pick up', 'D'],
#    'before_state': ({'B': 'sky', 'D': 'sky', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'table', 'D': 'table', 'C': 'table'},
#     None),
#    'after_state': ({'B': 'sky', 'D': 'sky', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'table', 'D': 'table', 'C': 'table'},
#     'D')},
#   {'idx': 1495,
#    'action': ['stack', 'D', 'B'],
#    'before_state': ({'B': 'sky', 'D': 'sky', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'table', 'D': 'table', 'C': 'table'},
#     'D'),
#    'after_state': ({'B': 'D', 'D': 'sky', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'table', 'D': 'B', 'C': 'table'},
#     None)},
#   {'idx': 1495,
#    'action': ['pick up', 'A'],
#    'before_state': ({'B': 'D', 'D': 'sky', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'table', 'D': 'B', 'C': 'table'},
#     None),
#    'after_state': ({'B': 'D', 'D': 'sky', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'table', 'D': 'B', 'C': 'table'},
#     'A')},
#   {'idx': 1495,
#    'action': ['stack', 'A', 'D'],
#    'before_state': ({'B': 'D', 'D': 'sky', 'A': 'sky', 'C': 'sky'},
#     {'A': 'table', 'B': 'table', 'D': 'B', 'C': 'table'},
#     'A'),
#    'after_state': ({'B': 'D', 'D': 'A', 'A': 'sky', 'C': 'sky'},
#     {'A': 'D', 'B': 'table', 'D': 'B', 'C': 'table'},
#     None)},
#   {'idx': 1495,
#    'action': ['pick up', 'C'],
#    'before_state': ({'B': 'D', 'D': 'A', 'A': 'sky', 'C': 'sky'},
#     {'A': 'D', 'B': 'table', 'D': 'B', 'C': 'table'},
#     None),
#    'after_state': ({'B': 'D', 'D': 'A', 'A': 'sky', 'C': 'sky'},
#     {'A': 'D', 'B': 'table', 'D': 'B', 'C': 'table'},
#     'C')},
#   {'idx': 1495,
#    'action': ['stack', 'C', 'A'],
#    'before_state': ({'B': 'D', 'D': 'A', 'A': 'sky', 'C': 'sky'},
#     {'A': 'D', 'B': 'table', 'D': 'B', 'C': 'table'},
#     'C'),
#    'after_state': ({'B': 'D', 'D': 'A', 'A': 'C', 'C': 'sky'},
#     {'A': 'D', 'B': 'table', 'D': 'B', 'C': 'A'},
#     None)}],
#  'pos': 2316,
#  'phrase': 'Let me go through the steps again.'}

# %%
def label_to_state(label):
    above = {}
    below = {}
    for i in range(n_blocks):
        below_block = int2block(label[i])
        above_block = int2block(label[i + n_blocks])
        block = int2block(i)

        above[block] = above_block
        below[block] = below_block

    return above, below, None

# %%
item_hidden_states = layer_hidden_states[0][item["idx"]]
pos = item["pos"]
inputs = torch.tensor(item_hidden_states[pos:pos + 5]).float().unsqueeze(0).to(device)

for j, probe in probes.items():
    with torch.no_grad():
        output = probe(inputs)
    # output = output.view(-1, n_blocks + 2, n_blocks * 2)
    preds = output.argmax(dim=-2).cpu().numpy().squeeze()

    print(label_to_state(preds))
    print(label_to_state(state_to_label(item["group"][j]["after_state"])))
    print()
# Out:
# ({'A': 'sky', 'B': 'sky', 'C': 'B', 'D': 'B'}, {'A': 'table', 'B': 'D', 'C': 'table', 'D': 'table'}, None)
# ({'A': 'sky', 'B': 'sky', 'C': 'sky', 'D': 'B'}, {'A': 'table', 'B': 'D', 'C': 'table', 'D': 'table'}, None)
#
# ({'A': 'sky', 'B': 'sky', 'C': 'B', 'D': 'B'}, {'A': 'table', 'B': 'D', 'C': 'table', 'D': 'table'}, None)
# ({'A': 'sky', 'B': 'sky', 'C': 'sky', 'D': 'B'}, {'A': 'table', 'B': 'D', 'C': 'table', 'D': 'table'}, None)
#
# ({'A': 'sky', 'B': 'sky', 'C': 'B', 'D': 'sky'}, {'A': 'table', 'B': 'C', 'C': 'table', 'D': 'table'}, None)
# ({'A': 'sky', 'B': 'sky', 'C': 'sky', 'D': 'sky'}, {'A': 'table', 'B': 'table', 'C': 'table', 'D': 'table'}, None)
#
# ({'A': 'sky', 'B': 'sky', 'C': 'sky', 'D': 'sky'}, {'A': 'table', 'B': 'table', 'C': 'table', 'D': 'table'}, None)
# ({'A': 'sky', 'B': 'sky', 'C': 'sky', 'D': 'sky'}, {'A': 'table', 'B': 'table', 'C': 'table', 'D': 'table'}, None)
#
# ({'A': 'sky', 'B': 'sky', 'C': 'sky', 'D': 'sky'}, {'A': 'table', 'B': 'table', 'C': 'table', 'D': 'table'}, None)
# ({'A': 'sky', 'B': 'sky', 'C': 'sky', 'D': 'sky'}, {'A': 'table', 'B': 'table', 'C': 'table', 'D': 'table'}, None)
#
# ({'A': 'D', 'B': 'D', 'C': 'D', 'D': 'sky'}, {'A': 'table', 'B': 'table', 'C': 'table', 'D': 'B'}, None)
# ({'A': 'sky', 'B': 'D', 'C': 'sky', 'D': 'sky'}, {'A': 'table', 'B': 'table', 'C': 'table', 'D': 'B'}, None)

# %%
print(dataset[5]["generation"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(dataset[5]["generation"])
#
# NameError: name 'dataset' is not defined

# %%
def find_index_before_block(text):
    text = text.lower()
    regex = r"\d+\.\s*(?:unstack|put down|pick up|stack)\s+(?:block\s+)?([a-z])"

    match = re.search(regex, text)
    
    return match.start(1) if match else None

for item in training_data:
    row = dataset[item["idx"]]
    tokens = tokenize_blocksworld_generation(tokenizer, row)[0]
    pos = item["pos"]

    # s = tokenizer.decode(tokens[pos:pos+20])

    # i = find_index_before_block(s)

    print(repr(tokenizer.decode(tokens[pos:pos+20])))
    print(repr(item["phrase"]), item["idx"])
    print(s[i:])
    print()
# Out:
# ' C.\n3. Stack D on B.\n4. Stack A on D.\n\nBut initially, C'
# 'Let me try to outline the desired final stack: A on D on B on C. So the order from bottom to top is C, B, D, A.' 0
#
#
# ' A\n2. Put down D\n3. Unstack A from C\n4. Put down'
# 'So the plan would be:' 1
#
#
# ' C. Now, B is in hand, C is on D, D is on table, A'
# 'Wait, let me outline the steps:' 2
#
#
# ' D. Now, C is in hand, D is on B, and A is on table.'
# 'Wait, let me think step by step.' 3
#
#
# ' on top of Block A.\n\n2. Put down Block C.\n\n3. Unstack Block A from'
# 'So, the plan would be:' 4
#
#
# ' D. Now, C is in my hand, and D is on the table, clear.\n\n2'
# 'Let me think about how to do this step by step.' 5
#
#
# ' B: valid because D is on top of B and D is clear.\n\n2. Put down D'
# 'Let me go through each step:' 6
#
#
# ' on top of Block D. Now, Block B is in my hand, and Block D is now'
# 'Let me try that.' 7
#
#
# ' A.\n\n2. Stack B on C.\n\n3. Then stack D on B.\n\nBut to do'
# 'Alternatively, maybe I can rearrange the order:' 8
#
#
# ' B. (D in hand, B on A on C)\n\n2. Put down D on table'
# 'Let me outline that plan again:' 9
#
#
# ' Block D. Now, Block A is in hand, Block D is clear.\n2. Put down'
# 'Let me outline the steps:' 10
#
#
# ' C. (D is in hand)\n2. Put down D. (D on table)\n3'
# 'Let me go through the plan again.' 11
#
#
# ' C\n2. Put down D\n3. Unstack C from B\n4. Put down'
# 'So the plan is:' 12
#
#
# ' D. Now, A is in hand, D is on table, clear.\n2. Put down'
# 'First, I need to get A off of D. Since A is clear, I can unstack A from D.' 13
#
#
# '2. Put down A\n3. Unstack B from D\n4. Stack B on A'
# 'Let me list them again:' 14
#
#
# ' A. Now, D is in hand, and A is clear again because D was on top.'
# 'Let me see:' 15
#
#
# ' A.\n2. Put down B.\n3. Unstack A from D.\n4. Put down'
# 'So the plan would be:' 16
#
#
# ' C. D in hand, C clear.\n2. Put down D. D on table.\n3'
# 'Let me try that.' 17
#
#
# ' C. Now, D is in hand, C is on table.\n\n2. Put down D.'
# "So, let's try this approach:" 18
#
#
# ' D\n2. Put down A\n3. Unstack D from B\n4. Put down'
# 'So the plan would be:' 19
#
#
# '2. Put down Block A.\n\n3. Unstack Block B from Block C.\n\n4. Stack'
# 'So, the plan is:' 20
#
#
# ' A.\n\n2. Put down D.\n\n3. Unstack A from C.\n\n4. Put down'
# 'So the plan would be:' 21
#
#
# ' D. Now, C is in hand, D is on A, which is on B.\n\n2'
# 'First, unstack C from D. So:' 22
#
#
# " D. Now I'm holding C, and D is on B, clear.\n2. Put down"
# 'So let me outline the steps:' 23
#
#
# ' C: Now, D is in hand, C is clear.\n2. Put down D: D'
# 'Let me think about the steps.' 24
#
#
# ' C\n2. Put down D\n3. Unstack C from B\n4. Stack C'
# 'So the plan is:' 25
#
#
# ' Block D\n2. Put down Block C\n3. Unstack Block D from Block A\n'
# 'So the plan would be:' 26
#
#
# ' A\n2. Put down B\n3. Pick up C\n4. Stack C on A'
# 'So the plan would be:' 27
#
#
# ' D.\n2. Put down C.\n3. Unstack D from A.\n4. Put down'
# 'So let me recap the steps:' 28
#
#
# ' B. Now, D is in hand, B is on the table, clear.\n2. Put'
# 'Let me outline possible steps:' 29
#
#
# ' B. (D in hand)\n2. Put down D. (D on table)\n3.'
# 'So the correct plan would be:' 30
#
#
# ' D.\n2. Put down A.\n3. Unstack B from C.\n4. Put down'
# 'So the plan would be:' 31
#
#
# ' D: Yes, because A is on top of D and A is clear.\n\n2. Put down'
# "Wait, but the goal is Block A on D, C on A, and D on B. So that's exactly what I have now. So the steps would be:" 32
#
#
# ' D. But wait, B is on top of D, so I can unstack B from D'
# 'Let me outline the steps:' 33
#
#
# ' B. Now, A is in hand, B is on D, C is on table.\n2'
# 'Let me go through the plan again.' 34
#
#
# "since it's clear and on table? Wait, no, A is on C, which is on"
# 'Let me go through each action:' 35
#
#
# ' A, put D down on the table.\n\n2. Now, A is on C, D is'
# 'Alternative approach:' 36
#
#
# ' C.\n2. Put down A.\n3. Unstack C from D.\n4. Put down'
# 'Let me recount:' 37
#
#
# ' C, put down A. Now, A is on the table, C is on D, B'
# 'So, perhaps the steps should be:' 38
#
#
# ' A.\n\n2. Put down C.\n\n3. Pick up B.\n\n4. Stack B on D'
# 'So the plan would be:' 40
#
#
# ' A. Now, B is on the table, A is on D, C is on the table'
# 'Let me outline the steps:' 41
#
#
# ' Block D. Now, Block C is in hand, Block D is clear.\n2. Put down'
# 'So, let me outline the steps:' 42
#
#
# ' C. Now, D is in hand, C is on A, and A is on the table'
# 'Let me outline the steps:' 43
#
#
# ' D.\n2. Put down Block B.\n3. Unstack Block D from C.\n4.'
# 'So the plan is:' 44
#
#
# ' D\n2. Stack A on C\n3. Pick up D\n4. Stack D on'
# 'So the plan would be:' 45
#
#
# ' B: Now, D is in hand, B is on A, clear.\n2. Put down'
# 'Let me go through each action:' 46
#
#
# ' D. Now, A is in hand, D is on table, clear.\n\n2. Stack A'
# 'So the steps would be:' 47
#
#
# ' A: Now, D is in hand, A is on B, B is on table, C'
# 'Let me go through each action and check the state after each step.' 48
#
#
# '2. Stack A on C. Now, C has A on top, on D, which is'
# "So, let's try:" 49
#
#
# ' C. (Now, A is on the table, C is on D, which is on B'
# "Let me check the steps again to make sure I didn't miss anything." 50
#
#
# ' B: Valid, A is clear and on B.\n2. Put down A: Valid.\n3'
# 'Let me try to outline the correct steps again, ensuring that each action is valid.' 51
#
#
# ' D\n2. Put down A\n3. Unstack D from B\n4. Stack D'
# 'So the plan would be:' 52
#
#
# '2. Stack A on C\n3. Unstack B from D\n4. Put down B'
# 'Let me list the steps again:' 55
#
#
# ' C. Now, B is in hand, C is on the table, clear.\n2. Stack'
# 'Let me try:' 56
#
#
# ' C.\n2. Put down B.\n3. Unstack C from A.\n4. Put down'
# 'So the plan would be:' 58
#
#
# ' B. Now, A is in hand, B is on table, clear.\n2. Put down'
# 'So the steps would be:' 59
#
#
# '2. Stack C on A.\n3. Pick up B.\n4. Stack B on C.\n\n'
# 'So the plan would be:' 60
#
#
# ' D (hand has A)\n2. Put down A (A on table)\n3. Unstack'
# 'So let me try that:' 61
#
#
# " C. Now, I'm holding D.\n2. Put down D on the table. Now,"
# 'Let me outline the steps:' 62
#
#
# ' B: Hand is empty, A is clear, so allowed. Now, A is in hand,'
# 'Let me go through each action:' 63
#
#
# ' A\n2. Put down B\n3. Unstack A from C\n4. Put down'
# 'So, the plan would be:' 64
#
#
# ' B.\n2. Put down C.\n3. Unstack B from A.\n4. Put down'
# 'Therefore, for this problem, the plan would be:' 65
#
#
# ' A\n2. Put down C\n3. Unstack A from D\n4. Put down'
# 'So the plan would be:' 66
#
#
# ' B.\n2. Put down C.\n3. Unstack D from A.\n4. Put down'
# 'So, the plan would be:' 67
#
#
# ' C.\n2. Put down B.\n3. Pick up D.\n4. Stack D on C'
# 'So, the plan would be:' 68
#
#
# ' A. Hand is empty, B is clear. So, I can do this. Now, B'
# 'So, step by step:' 69
#
#
# ' B.\n\n2. Put down A.\n\n3. Pick up D.\n\n4. Stack D on C'
# 'So, the plan would be:' 71
#
#
# ' D. Hand has A.\n\n2. Stack A on C. But wait, C is under D'
# 'Yes, all steps are valid. So the plan is:' 72
#
#
# ' A: valid because D is on top of A and clear.\n\n2. put down D: valid'
# 'So the plan would be:' 73
#
#
# ' D\n2. Put down A\n3. Unstack D from B\n4. Put down'
# 'Let me recap:' 74
#
#
# '2. Unstack B from C.\n3. Put down B.\n4. Unstack C from'
# 'Let me go through the steps again:' 75
#
#
# ' C\n2. Put down A\n3. Unstack C from D\n4. Put down'
# 'So the plan would be:' 76
#
#
# ' D. (B is in hand, D is on table, clear)\n\n2. Put down B'
# 'Let me write the steps again:' 77
#
#
# ' A. Hand holds B.\n2. Put down B. Now, B is on table.\n3'
# 'So, the steps would be:' 78
#
#
# '2. Stack C on D. Now, D has C on top, so D is no longer'
# 'Let me outline the steps:' 79
#
#
# ' B. Now, D is in hand, B is clear.\n2. Put down D. Now'
# 'Let me outline the steps:' 81
#
#
# ' B.\n\n2. Put down C.\n\n3. Unstack B from D.\n\n4. Put down'
# 'So the steps would be:' 82
#
#
# " A. Now I'm holding C, and A is on top of B, which is on the"
# 'Let me outline the steps:' 83
#
#
# ' B\n2. Put down A\n3. Unstack B from C\n4. Put down'
# 'So the steps would be:' 84
#
#
# ' A: allowed because C is clear and on top of A.\n2. Put down C: allowed'
# 'Let me think about the steps.' 85
#
#
# ' A. (D is in hand, A is on C)\n\n2. Put down D on table'
# 'Let me recount:' 87
#
#
# ' A: Valid because C is on top of A and clear.\n2. Put down C: Valid'
# 'Let me go through each step:' 88
#
#
# ' A. Now, B is in hand, A is on D, D is on C.\n\n2'
# 'So the correct order is:' 90
#
#
# '2. Stack D on C.\n3. Pick up B.\n4. Stack B on D.\n'
# 'But let me outline the steps:' 91
#
#
# ' A. Now, B is in hand, A is on table.\n2. Put down B.'
# "Let's plan step by step." 92
#
#
# ' D\n2. Put down B\n3. Unstack D from C\n4. Put down'
# 'So the plan would be:' 93
#
#
# ' C.\n2. Put down B.\n3. Unstack C from A.\n4. Put down'
# 'So, to recap, the plan is:' 94
#
#
# ' A.\n\n2. Put down D.\n\n3. Unstack C from B.\n\n4. Put down'
# 'So, the plan would be:' 95
#
#
# ' B\n2. Put down D\n3. Unstack B from A\n4. Stack A'
# 'So, the steps are:' 96
#
#
# '6. Stack A on B (now stack is B -> A)\n7. Hand is empty.\n\n'
# "So let's proceed step by step." 97
#
#
# ' A.\n2. Put down C.\n3. Pick up A.\n4. Stack A on C'
# 'So the steps would be:' 98
#
#
# ' D. Now, B is in hand, D is on table, clear.\n\n2. Put down'
# 'So, the steps would be:' 99
#
#
# ' D. Now, C is in hand, D is on the table, clear.\n2. Put'
# 'Let me outline the steps:' 100
#
#
# '2. Stack B on D.\n3. Pick up A.\n4. Stack A on B.\n'
# 'So the plan would be:' 101
#
#
# ' B: valid because D is on top of B and clear.\n2. Put down D: valid'
# 'Let me go through each action:' 102
#
#
# ' D. Hand holds B. (B was clear, D was clear after B is removed)\n\n2'
# 'So the plan would be:' 103
#
#
# ' D: Possible because B is clear and on top of D.\n2. Put down B: Hand'
# 'Let me think about the steps.' 104
#
#
# ' A. Now, D is in hand, A is on C, B on table.\n2.'
# 'I think the correct approach is:' 105
#
#
# ' A.\n\n2. Put down C.\n\n3. Unstack A from B.\n\n4. Put down'
# 'So the steps would be:' 106
#
#
# ' B. Now, A is in hand, B is clear.\n2. Put down A on the'
# 'Let me outline the steps:' 107
#
#
# ' D. Now, B is in hand, D is on the table, and the stack D is'
# 'Let me outline the steps:' 108
#
#
# ' B. Now, A is in my hand, and B is on D, which is on C'
# 'Let me correct the steps:\n\nAfter step 6, all blocks are on the table. So:' 109
#
#
# ' C. Now, D is in hand, C is on the table.\n2. Put down D'
# 'Let me go through each action step by step.' 110
#
#
# '2. Stack B on C.\n3. Pick up A.\n4. Stack A on B.\n\n'
# 'So the plan would be:' 111
#
#
# ' D: Hand is empty, B is on top of D, and B is clear. So this'
# 'Let me go through each action and ensure I followed the rules.' 112
#
#
# ' A. Now, D is in hand, A is on the table, clear.\n2. Put'
# 'So, the plan would be:' 113
#
#
# ' A. Now, D is in hand, A is on B, C is on table, hand'
# 'Let me outline the steps:' 114
#
#
# ' A.\n2. Put down B.\n3. Unstack C from D.\n4. Put down'
# 'So, the plan would be:' 115
#
#
# ' B, put down A.\n2. Unstack B from C, put down B.\n3.'
# 'So, the plan would be:' 116
#
#
# ' B: Now, A is in hand, B is clear.\n2. Put down A: A'
# 'Let me think about the steps.' 118
#
#
# ' B. (Hand holds D)\n2. Put down D. (D on table)\n3.'
# 'Let me outline the steps:' 119
#
#
# ' B. (C is now in hand, B on D on A, C clear on table after'
# 'So steps:' 120
#
#
# ' C. Now, B is on the table, C is on the table.\n2. Put down'
# 'Let me outline the steps:' 121
#
#
# ' C.\n\n2. Put down B.\n\n3. Unstack C from D.\n\n4. Put down'
# 'So the plan is:' 122
#
#
# ' A. Hand holds B.\n2. Put down B. Now, B is on table.\n3'
# 'Let me go through the steps again:' 123
#
#
# ' B\n2. Put down A\n3. Unstack B from D\n4. Put down'
# 'Let me recount:' 124
#
#
# ' C, put down D.\n2. Unstack C from B, put down C.\n3.'
# 'Let me recount the steps:' 125
#
#
# ' A\n2. Stack D on B\n3. Unstack D from B\n4. Stack'
# 'So, the plan would be:' 126
#
#
# ' D\n2. Put down C\n3. Pick up B\n4. Stack B on D'
# 'So the plan would be:' 127
#
#
# ' D.\n\n2. Put down C.\n\n3. Unstack D from B.\n\n4. Put down'
# 'So the plan would be:' 128
#
#
# ' D. (C is clear, so yes)\n2. Put down C.\n3. Unstack'
# 'Let me go through the plan again.' 129
#
#
# ' B. C on table, B on A, A on D.\n\n2. Put down C.\n\n'
# 'Let me try:' 130
#
#
# ' A.\n2. Put down D.\n3. Unstack B from C.\n4. Stack B'
# 'So, the plan would be:' 131
#
#
# ' D\n2. Put down A\n3. Pick up D\n4. Stack D on A'
# 'Yes, all steps seem valid. So the plan should be:' 132
#
#
# ' B. Now, C is on the table, B is on D, D is on the table'
# 'Let me write them out step by step:' 133
#
#
# ' Block C. Now, B is in hand, C is on the table, clear.\n\n2.'
# 'Let me outline the steps:' 134
#
#
# ' B. (A is in hand)\n\n2. Stack A on D. (A is on D'
# 'So, the steps would be:' 135
#
#
# ' A: Yes, D is on A, clear, so I can unstack it. Hand now'
# "Let me go through each step and see if I'm following the rules." 136
#
#
# ' B.\n\n2. Put down A.\n\n3. Unstack B from C.\n\n4. Put down'
# 'So the plan should be:' 137
#
#
# ' A. But to do that, I need to pick up D, but D is on top of'
# 'So, the steps I need to take are:' 141
#
#
# ' B\n\n2. put down C\n\n3. unstack B from A\n\n4. put down'
# 'So the plan would be:' 142
#
#
# ' C.\n2. Put down D.\n3. Unstack C from B.\n4. Stack C'
# 'So the plan would be:' 143
#
#
# ' C.\n\n2. Put down D.\n\n3. Unstack C from B.\n\n4. Put down'
# 'So, the plan is:' 145
#
#
# ' C.\n2. Put down D somewhere, maybe on the table.\n3. Then unstack C'
# 'So the order would be:' 146
#
#
# '8. Stack Block C on top of Block D. Now, Block C is on Block D,'
# 'So:' 147
#
#
# ' A.\n\n2. Stack B on D.\n\nBut wait, D is on the table, clear.'
# 'Wait, after unstacking B from A, I can put B on D, but D is on the table.' 148
#
#
# ' C\n2. Stack D on A\n3. Unstack C from B\n4. Stack'
# 'So, the plan would be:' 149
#
#
# ' C. (Now, B is in hand, C is clear)\n2. Put down B.'
# 'Let me go through the steps again:' 150
#
#
# ' D.\n\n2. Put down A.\n\n3. Unstack D from B.\n\n4. Put down'
# 'So the plan is:' 151
#
#
# ' D.\n\n2. Put down C.\n\n3. Unstack D from B.\n\n4. Put down'
# 'So the plan would be:' 152
#
#
# ' A\n2. Put down D\n3. Unstack A from C\n4. Put down'
# 'So the plan would be:' 154
#
#
# ' B. Now, C is on the table, B is on the table, A is on the'
# 'So let me outline the steps:' 155
#
#
# ' A.\n\n2. Put down C.\n\n3. Unstack A from D.\n\n4. Put down'
# 'So the steps would be:' 156
#
#
# ' C.\n2. Put down D.\n3. Unstack C from B.\n4. Put down'
# "Let me recount the steps to make sure I didn't miss anything." 157
#
#
# ' B: A is clear, hand is empty, so allowed.\n2. Put down A: Hand'
# 'First, I need to get Block A off Block B because in the goal, A is under C, not on B.' 158
#
#
# ' B\n2. Put down A\n3. Unstack B from C\n4. Put down'
# 'So the plan is:' 159
#
#
# ' D. Now, B in hand, D on A, C on table.\n\n2. Put down'
# 'Alternative approach:' 160
#
#
# ' A\n2. Put down B\n3. Pick up A\n4. Stack A on B'
# 'Let me think step by step.' 161
#
#
# ' D. Hand holds B.\n2. Put down B. Now, B is on the table.\n'
# 'So, the plan is:' 163
#
#
# ' C. Now, D is in hand, C is on the table.\n2. Put down D'
# 'Let me outline the steps:' 164
#
#
# ' C. (Now, B is in hand, C is clear)\n2. Put down B.'
# 'Let me outline the steps clearly:' 165
#
#
# ' D. Now, C is on the table, D is on the table, B is on C'
# 'Let me outline the steps:' 166
#
#
# ' A\n2. Put down B\n3. Unstack A from D\n4. Put down'
# 'So the plan would be:' 167
#
#
# ' B. Hand is holding A. Then put down A. Now, A is on the table,'
# 'So, let me outline the steps:' 168
#
#
# ' C. (Since D is clear and on top of C, this is allowed.)\n\n2. Put'
# 'Let me write the plan step by step, making sure each action is valid according to the rules.' 169
#
#
# ' B\n2. Put down A\n3. Unstack B from C\n4. Put down'
# 'So the plan would be:' 170
#
#
# ' A: Hand is empty, C is clear, so allowed. Now holding C.\n2. Put'
# 'Let me go through each action:' 172
#
#
# '2. Stack C on D\n3. Pick up B\n4. Stack B on C\n'
# 'So the steps would be:' 173
#
#
# ' A.\n2. Put down B.\n3. Unstack A from C.\n4. Put down'
# 'So, the steps would be:' 174
#
#
# ' B. (D is in hand, B is clear)\n2. Put down D. (D'
# 'Let me go through the steps again:' 175
#
#
# ' B: Is D on top of B? Yes. Is D clear? Yes, because nothing is'
# 'Let me go through each action and check the conditions.' 176
#
#
# ' A.\n2. Put down C.\n3. Pick up D.\n4. Stack D on C'
# 'So the steps would be:' 177
#
#
# ' A. Now, A is on the table, D is in hand.\n2. Stack D on'
# 'Let me think about the steps.' 178
#
#
# ' C.\n\n2. Put down A.\n\n3. Unstack C from D.\n\n4. Put down'
# 'So, the plan is:' 179
#
#
# ' A. (D is now in hand, A on C, B on table)\n\n2. Put'
# 'Let me outline the steps again:' 180
#
#
# ' C. Now, A is in hand, and C is on D, which is on B.\n\n'
# 'So, I think I need to start by unstacking A from C.' 181
#
#
# ' A, put D down. Now, A is on the table, D is on the table.\n\n'
# 'So, the steps I need to take are:' 182
#
#
# ' B: Now, A is in hand, B is clear on table.\n2. Unstack D'
# 'Let me go through each action and check the state after each step.' 183
#
#
# ' Valid because A is clear and on the table (actually, A is on B, but since B'
# 'Let me go through each step:' 184
#
#
# ' A: valid because D is on A, and D is clear.\n\n2. put down D:'
# 'So the plan would be:' 185
#
#
# ' Block D\n2. Put down Block C\n3. Unstack Block D from Block B\n'
# 'So the plan would be:' 186
#
#
# ' C\n2. Put down D\n3. Pick up D\n4. Stack D on B'
# 'So the plan would be:' 187
#
#
# '2. Put down Block B.\n\n3. Unstack Block A from Block D.\n\n4. Put'
# 'So, the plan would be:' 188
#
#
# '2. Put down A.\n3. Unstack C from B.\n4. Put down C.\n'
# 'So the plan is:' 189
#
#
# ' C\n2. Put down B\n3. Unstack C from D\n4. Put down'
# 'So the plan would be:' 190
#
#
# ' Block A.\n2. Stack Block C on Block D.\n3. Unstack Block A from Block'
# 'Let me go through the plan again.' 191
#
#
# ' Block A\n2. Stack Block B on Block C\n3. Unstack Block A from Block'
# 'So, the plan would be:' 192
#
#
# ' D.\n2. Put down A.\n3. Unstack B from C.\n4. Put down'
# 'So the plan would be:' 193
#
#
# "since it's on the table and clear)\n2. Stack D on top of A (since A"
# 'So, the steps would be:' 194
#
#
# ' A\n2. put down B\n3. unstack A from D\n4. put down'
# 'So the steps would be:' 196
#
#
# ' Block A.\n2. Stack Block B on top of Block C.\n3. Pick up Block A'
# 'Yes, that works! So the plan is:' 197
#
#
# ' D\n2. Put down C\n3. Unstack D from A\n4. Put down'
# 'So the plan would be:' 198
#
#
# ' D (hand holds A)\n2. Stack A on B (A is on B, hand empty'
# 'Let me try:' 199
#
#
# ' B: valid because A is clear and on top of B.\n2. Put down A: valid'
# 'Let me think about the steps needed.' 200
#
#
# ' C, put down D.\n2. Unstack C from A, put down C.\n3.'
# 'But let me go through each action:' 201
#
#
# ' D. (Now, A is in hand, D is on C on B)\n\n2. Put'
# 'Let me outline the steps clearly:' 203
#
#
# ' B.\n2. Put down D.\n3. Pick up C.\n4. Stack C on B'
# 'So, the plan would be:' 205
#
#
# ' D: C is clear, D is on A. So, I can unstack C. Now'
# 'Let me go through each step again:' 206
#
#
# ' A. Now, C is in hand, A is clear.\n2. Put down C. Now'
# "So let's plan:" 207
#
#
# ' Hand holds A. Stack is D-B-C.\n2. Put down A. A is on table'
# 'Let me go through each step:' 208
#
#
# ' on top of Block D.\n\n2. Put down Block A.\n\n3. Unstack Block C from'
# 'Let me write it out step by step:' 209
#
#
# ' D. Now, B is in hand, D is on table, clear.\n\n2. Put down'
# 'So, the steps I need to take are:' 210
#
#
# ' D\n2. Put down A\n3. Unstack D from B\n4. Put down'
# 'So the initial steps must be:' 211
#
#
# ' A. Hand holds D.\n\n2. Put down D on the table.\n\n3. Unstack A'
# 'Wait, let me try:' 212
#
#
# ' on top of Block A. Now, B is in my hand, and A is clear again because'
# 'Let me think about the steps.' 213
#
#
# ' D\n2. Put down A\n3. Pick up B\n4. Stack B on A'
# 'Let me write them out clearly:' 214
#
#
# ' Block D.\n\n2. Put down Block C (though in this case, after unstacking,'
# 'So the plan would be:' 215
#
#
# ' A.\n2. Put down C.\n3. Unstack A from B.\n4. Put down'
# 'So the plan would be:' 216
#
#
# ' D. (B is now in hand, D on table)\n\n2. Put down B. ('
# 'Let me list them again clearly:' 217
#
#
# ' A.\n2. Stack C on B.\n3. Pick up A.\n4. Stack A on'
# 'Let me try to write the plan:' 219
#
#
# ' A.\n\n2. Put down D.\n\n3. Unstack A from B.\n\n4. Put down'
# 'Let me recount:' 220
#
#
# ' D\n2. Put down C\n3. Unstack B from A\n4. Put down'
# 'Let me go through each action:' 221
#
#
# ' B. (C is now on table, B on A on D)\n2. Put down C'
# "But let me go through the steps again to make sure I didn't miss anything." 222
#
#
# ' A, put down C. Now, A is on table, C is on table.\n2.'
# 'Wait, let me outline the steps:' 223
#
#
# ' on top of Block D.\n\n2. Stack Block C on top of Block B.\n\n3. Un'
# 'So let me adjust the plan:' 224
#
#
# ' B: valid because D is on top of B and clear.\n2. Put down D: valid'
# 'Let me go through each step:' 225
#
#
# ' A.\n\n2. Put down B.\n\n3. Unstack C from D.\n\n4. Put down'
# 'So the plan should be:' 226
#
#
# ' D. (Now holding C)\n2. Put down C. (C is on table)\n3'
# 'Let me go through the plan again.' 227
#
#
# ' A: Valid because D is on top of A and clear.\n2. Put down D: Valid'
# 'So step 1: Unstack D from A.' 228
#
#
# ' D.\n2. Stack B on A.\n3. Pick up D.\n4. Stack D on'
# 'So the plan is:' 229
#
#
# ' B.\n2. Put down C.\n3. Unstack B from A.\n4. Put down'
# 'Let me go through the steps again:' 230
#
#
# ' C. Now, B is in hand, C is on the table.\n2. Put down B'
# 'Let me go through each step:' 231
#
#
# ' C\n2. Put down D\n3. Unstack C from A\n4. Put down'
# 'So the steps are:' 233
#
#
# ' D. Now, C is in hand, D is on B.\n2. Stack C on A'
# "Let me double-check the steps to make sure I didn't miss anything." 234
#
#
# ' B. (C is clear, B is on A, which is on D. So C can'
# 'Let me list the steps again with more detail:' 235
#
#
# ' C.\n2. Put down B.\n3. Unstack C from A.\n4. Put down'
# 'So the plan would be:' 236
#
#
# ' B. So I need to pick up C and stack it on B.\n\nBut wait, to stack'
# 'So the steps would be:' 237
#
#
# ' D. A in hand.\n\n2. Put down A.\n\n3. Unstack D from C.'
# 'So:' 238
#
#
# ' B: D is on top of B, which is on top of C. D is clear,'
# 'So, the plan would be:' 239
#
#
# ' D.\n2. Put down B.\n3. Pick up D.\n4. Stack D on A'
# 'So the plan would be:' 240
#
#
# ' B.\n\n2. Put down C.\n\n3. Unstack B from D.\n\n4. Put down'
# 'So, to recap, the plan is:' 241
#
#
# ' A. Hand holds D. Then put down D on the table.\n\n2. Unstack A from'
# 'So let me outline the steps with the correct actions:' 242
#
#
# ' B.\n2. Put down A.\n3. Unstack D from C.\n4. Put down'
# 'So, the plan would be:' 243
#
#
# ' B. Now, C is on the table, stack is A -> D -> B.\n\n2.'
# 'Let me go through the plan again.' 244
#
#
# ' B\n\n2. stack D on A\n\n3. unstack D from A\n\n4. stack'
# 'So, the plan would be:' 246
#
#
# ' B. Hand holds A.\n2. Put down A on table.\n3. Unstack B from'
# 'So steps:' 247
#
#
# ' B, put it down. Now D is on the table, B is on C, A is'
# 'So the steps would be:' 248
#
#
# ' B. (A is in hand)\n2. Put down A. (A on table)\n3'
# 'Let me recount:' 249
#
#
# ' C. \n2. Put down D. \n3. Unstack C from A. \n4'
# 'Let me outline it clearly:' 250
#
#
# ' A. Now, D is on the table, A is on C.\n\n2. Unstack A'
# 'So the correct order would be:' 251
#
#
# ' C.\n2. Put down B.\n3. Unstack D from A.\n4. Put down'
# 'So the plan would be:' 252
#
#
# ' A: Since D is on top of A and D is clear, I can unstack it.'
# 'So let me think step by step:' 253
#
#
# ' B.\n2. Put down D.\n3. Pick up C.\n4. Stack C on A'
# 'So, the plan would be:' 254
#
#
# ' B.\n2. Put down A.\n\nNow, with B clear, I can pick up B.'
# 'So the plan so far is:' 255
#
#
# ' D: Now A is on the table, D is on C, but D is clear because A'
# 'Let me go through each action:' 256
#
#
# ' A. Now, D is in hand, A is on the table.\n2. Stack D on'
# 'Wait, let me outline the steps:' 257
#
#
# ' A.\n\n2. Put down B.\n\n3. Unstack A from D.\n\n4. Put down'
# 'So the steps are:' 258
#
#
# ' B\n2. Put down A\n3. Pick up B\n4. Stack B on A'
# 'So the plan is:' 259
#
#
# ' B.\n\n2. Put down D.\n\n3. Unstack B from A.\n\n4. Put down'
# 'So, the plan is:' 260
#
#
# ' A\n2. Put down B\n3. Unstack A from C\n4. Stack A'
# 'So the plan would be:' 263
#
#
# ' B. Now, D is in hand, B is on table, clear.\n2. Stack D'
# 'Let me think about the steps.' 264
#
#
# ' C.\n2. Put down B.\n3. Unstack C from A.\n4. Put down'
# 'So the plan would be:' 265
#
#
# ' B: Now, C is on table, B is on A, A on D.\n\n2.'
# 'Let me think about the steps.' 266
#
#
# ' B. Now, A is on the table, B is on D, D on C.\n2'
# 'Let me list them:' 267
#
#
# ' D\n\n2. Put down B\n\n3. Unstack D from C\n\n4. Put down'
# 'So the plan would be:' 268
#
#
# ' C. Now, A is in hand, C is clear.\n2. Put down A. Now'
# 'Let me go through each action:' 269
#
#
# ' C.\n2. Put down D.\n3. Pick up B.\n4. Stack B on C'
# 'So, the plan would be:' 270
#
#
# ' C\n\n2. put down B\n\n3. unstack C from D\n\n4. put down'
# 'So the plan would be:' 271
#
#
# ' D\n2. Put down A\n3. Unstack D from B\n4. Put down'
# 'So the plan would be:' 274
#
#
# ' D. Now, A is in hand, D is clear. \n\n2. Put down A.'
# 'Starting from the initial state: A on D, B and C on table, all clear.' 275
#
#
# ' A.\n2. Put down D.\n3. Unstack A from B.\n4. Put down'
# 'So, to summarize, the steps would be:' 276
#
#
# ' C. (D on table, C on B)\n2. Unstack C from B. ('
# 'Let me outline the steps:' 277
#
#
# ' C: Now, A is in hand, C is on B.\n2. Put down A:'
# 'Let me go through each action:' 278
#
#
# '2. Stack B on D\n3. Pick up C\n4. Stack C on B\n'
# 'So the plan is:' 279
#
#
# ' D.\n\n2. Stack A on B.\n\n3. Unstack D from C.\n\n4. Put'
# 'So the plan would be:' 281
#
#
# ' A, put down C. Now, A is on D, D on B, C is on'
# 'Let me try to outline the steps:' 282
#
#
# ' C. Hand holds D.\n2. Put down D. D is on table.\n3. Pick'
# 'So the steps would be:' 283
#
#
# ' A. (Now, B is in hand, A is clear)\n2. Put down B.'
# 'Let me write the plan step by step:' 284
#
#
# ' D\n2. Put down A\n3. Unstack D from B\n4. Put down'
# 'So the plan would be:' 285
#
#
# ' C\n2. Put down D\n3. Unstack C from A\n4. Put down'
# 'So the plan would be:' 286
#
#
# ' A: allowed because C is clear and on A.\n2. Put down C: allowed because hand'
# "Let me go through each action and ensure it's allowed." 288
#
#
# ' A. (D is now in hand, A is clear)\n2. Put down D on table'
# 'Let me go through the plan again.' 289
#
#
# ' B. Now, C is in hand, B is on the table, clear.\n2. Put'
# 'Let me outline the steps:' 290
#
#
# ' D (since A is on D and clear).\n2. Put down A on the table.\n3'
# 'So, step by step:' 291
#
#
# ' A. Hand holds B. A is now on the table, clear.\n\n2. Put down B'
# 'Let me outline this:' 292
#
#
# ' B. Hand now holds D. B is on table, clear.\n2. Put down D.'
# 'Let me go through each action:' 293
#
#
# ' B. Now, C is in hand, B is on the table, clear.\n2. Put'
# 'So the steps I need to take are:' 294
#
#
# ' A.\n\n2. Put down D.\n\n3. Unstack A from B.\n\n4. Put down'
# 'So the plan would be:' 295
#
#
# ' A: Valid because B is clear and on top of A.\n\n2. Put down B: Valid'
# "Let me go through each action and ensure it's valid." 296
#
#
# ' Hand is empty, A is clear and on C (which is on table). So yes, can'
# 'Let me go through each action:' 297
#
#
# ' B: valid because A is clear and on top of B.\n\n2. Put down A: valid'
# "Let me go through each action and see if it's valid." 298
#
#
# ' C: Now, B is in hand, C is on A.\n2. Put down B:'
# 'So the plan would be:' 299
#
#
# ' on top of Block B.\n2. Put down Block A.\n3. Unstack Block B from'
# 'Let me write the plan step by step:' 300
#
#
# ' C.\n\n2. Put down D.\n\n3. Unstack C from B.\n\n4. Put down'
# 'So the plan would be:' 301
#
#
# ' B.\n2. Stack C on D.\n3. Unstack A from C.\n4. Stack'
# 'So the plan would be:' 302
#
#
# ' D. Since B is clear, I can do that. After unstacking, B is in'
# 'Let me list the steps I think I need:' 303
#
#
# ' C. Now, holding B.\n\n2. Stack B on A. Now, B is on A'
# 'So, the steps would be:' 304
#
#
# ' C: Valid because A is on top of C and A is clear.\n\n2. Stack A on'
# 'Let me go through each step:' 305
#
#
# ' D: Yes, B is on top of D and clear. Hand becomes empty after unstacking'
# 'Putting it all together, the steps would be:' 306
#
#
# ' C.\n2. Put down A.\n3. Unstack C from D.\n4. Put down'
# 'So, the steps would be:' 307
#
#
# ' B.\n\n2. Put down A.\n\n3. Unstack B from D.\n\n4. Put down'
# 'So the steps would be:' 308
#
#
# ' B. (C in hand, B on table, clear)\n\n2. Put down C. ('
# 'Alternative plan:' 309
#
#
# ' C: Yes, because A is clear and on top of C.\n\n2. Put down A:'
# 'So the steps would be:' 310
#
#
# ' B. (Now holding C)\n2. Put down C. (C is on table)\n3'
# 'Let me go through each step again.' 311
#
#
# ' C. (A in hand, C on D)\n2. Put down A. (A on'
# 'Let me recount:' 312
#
#
# ' A\n2. Put down B\n3. Unstack D from C\n4. Put down'
# 'So the plan is:' 313
#
#
# ' D\n\n2. put down C\n\n3. unstack D from A\n\n4. pick up'
# 'So the plan would be:' 314
#
#
# ' C. (D is clear, on top of C)\n2. Put down D. (Hand'
# 'Let me try to write the plan step by step, ensuring each action is allowed.' 315
#
#
# ' D. Now, C is in hand, D is on table, clear.\n\n2. Stack C'
# 'Wait, let me try to outline the steps again:' 316
#
#
# ' A\n2. put down C\n3. unstack A from D\n4. put down'
# 'Alternatively, after unstacking D from B, D is on the table. Then I can pick up A, stack on D, then pick up C, stack on A, then pick up B, stack on C.' 319
#
#
# ' A: Valid because D is on A and D is clear.\n\n2. Put down D: Valid'
# 'Let me go through each step:' 320
#
#
# ' D.\n2. Put down B.\n3. Unstack D from C.\n4. Put down'
# "Yes, that's exactly what we have now. So the plan would be:" 321
#
#
# ' A. (D is in hand, A is clear)\n2. Put down D. (D'
# 'Let me go through the plan again:' 322
#
#
# '2. Stack B on C.\n3. Pick up D.\n4. Stack D on B.\n\n'
# 'So the steps are:' 324
#
#
# ' Block D.\n\n2. Put down Block B.\n\n3. Unstack Block C from Block A.\n\n'
# 'So the plan is:' 325
#
#
# ' B.\n\n2. Stack A on C.\n\n3. Unstack B from D.\n\n4. Stack'
# 'So, the plan is:' 326
#
#
# ' Now, D is on the table, and hand is empty.\n\n3. Now, I can un'
# 'Wait, let me think step by step.' 327
#
#
# ' C.\n2. Stack B on D.\n3. Pick up A.\n4. Stack A on'
# 'So, the steps would be:' 328
#
#
# ' B.\n\n2. Put down D.\n\n3. Unstack B from C.\n\n4. Put down'
# 'Let me try:' 329
#
#
# ' D. Now, A is in hand, D is clear.\n2. Put down A on the'
# "Let me recap the steps to make sure I didn't miss anything:" 330
#
#
# ' D.\n2. Put down C.\n3. Unstack D from A.\n4. Put down'
# "I think that's correct. So the plan should be:" 331
#
#
# ' B.\n2. Put down C.\n3. Unstack D from A.\n4. Put down'
# 'Let me think about the steps.' 332
#
#
# ' A, put down C. Now, C is on table, A is on D, B is'
# 'Let me go through the plan again.' 333
#
#
# ' D. Now, B is in hand, D is clear.\n2. Put down B on the'
# 'So, the correct order is:' 334
#
#
# '2. Put down Block A on the table.\n3. Now, Block C is clear. Pick'
# 'Let me outline the steps:' 335
#
#
# ' B. (A is in hand)\n2. Put down A. (A is on table)\n'
# 'Applying that to my problem:' 338
#
#
# ' C. Now D is in hand, C is on A, A is on table, B is'
# 'Step 1: unstack D from C.' 339
#
#
# ' on top of Block D.\n\n2. Put down Block A.\n\n3. Unstack Block D from'
# 'So the plan would be:' 341
#
#
# ' A.\n2. Put down C.\n3. Unstack B from D.\n4. Stack B'
# 'So the plan would be:' 342
#
#
# ' on top of Block B. (Now A is in hand, B is on table, clear)\n'
# 'So let me adjust the steps.' 343
#
#
# ' B\n2. Put down C\n3. Unstack B from D\n4. Put down'
# 'So the optimized plan would be:' 344
#
#
# ' B.\n\n2. Put down A.\n\n3. Unstack B from C.\n\n4. Put down'
# 'So the plan would be:' 345
#
#
# ' C. Now, B is in hand, C is clear.\n2. Put down B on the'
# 'Let me outline the steps:' 346
#
#
# ' C. Now, D is in hand, C is clear on table.\n2. Put down D'
# 'So maybe the steps are:' 348
#
#
# ' the table.\n\nNow, D is on B, A is on table, C is on table.\n\n'
# 'So let me think step by step.' 349
#
#
# ' D.\n\n2. Put down B.\n\n3. Unstack D from A.\n\n4. Put down'
# 'So the plan should be:' 350
#
#
# ' C. Now, A is in hand, C is clear.\n\n2. Put down A. Now'
# 'So, the steps would be:' 351
#
#
# ' A\n2. Put down D\n3. Pick up A\n4. Put down A\n'
# 'So the plan would be:' 352
#
#
# ' B. Now, A is in hand, B is on D.\n2. Put down A.'
# 'Let me outline the correct sequence:' 353
#
#
# ' Block C (since Block A is on top of Block C, but actually, Block A is on'
# 'Let me rephrase the steps using the exact actions:' 354
#
#
# ' D (hand now holds B)\n2. Put down B (hand empty)\n3. Pick up'
# 'So, the plan would be:' 355
#
#
# ' C. Now, A is in hand, C is on the table.\n2. Put down A'
# 'Let me list them out:' 356
#
#
# ' A. Now, B is in hand, A is clear.\n2. Put down B. Now'
# 'So the correct order is:' 358
#
#
# ' C.\n2. Put down A.\n3. Unstack B from A.\n4. Put down'
# 'So the plan is:' 359
#
#
# ' D. Now, C is on table, D is on B, clear.\n\n2. Pick up'
# 'Let me go through each step again.' 361
#
#
# ' C. Now, A is in hand, C is on table.\n2. Put down A.'
# 'So, the correct sequence would be:' 362
#
#
# ' D → B is on table, D is on A, hand holding B.\n\n2. Put down'
# 'So, perhaps the steps are:' 363
#
#
# ' B. Since A is clear, I can do that.\n\n2. Put down A on the table'
# 'Alternative approach:' 364
#
#
# ' D.\n\n2. Put down B.\n\n3. Unstack D from C.\n\n4. Stack D'
# 'So the plan is:' 365
#
#
# ' A\n2. Put down C\n3. Pick up B\n4. Stack B on D'
# 'So the correct order is:' 366
#
#
# ' Block D.\n2. Stack Block B on Block A.\n3. Unstack Block D from Block'
# 'So, the plan would be:' 367
#
#
# ' A. (Now, C is on table, A on D, hand empty.)\n2. Put'
# 'Let me go through the plan again.' 368
#
#
# ' Block A. (Now, Block B is in hand, Block A is on Block C)\n2'
# 'So, let me try that approach:' 369
#
#
# ' A. D in hand, A on table.\n2. Put down D on table. D on'
# 'Let me try:' 370
#
#
# ' B. Now, C is on the table, B is on D, which is on A.\n\n'
# 'Let me go through each step:' 371
#
#
# ' A. Now, C is on the table, A is on D, B is on the table'
# 'Let me outline the steps:' 372
#
#
# ' C.\n\n2. Put down D.\n\n3. Unstack C from B.\n\n4. Stack C'
# 'So the plan would be:' 373
#
#
# ' B, put down C.\n2. Unstack B from D, put down B.\n3.'
# 'Wait, but the goal is D on B, A on D, and C on A. So, that would be B-D-A-C. So, the steps would be:' 374
#
#
# ' C: Now D is on the table, stack is A-B-C.\n2. Put down D'
# 'Let me go through each action:' 375
#
#
# ' C.\n2. Put down B.\n3. Unstack C from D.\n4. Put down'
# 'So the plan would be:' 376
#
#
# ' B.\n2. Stack D on C.\n3. Unstack B from A.\n4. Pick'
# "Let me recap the steps to make sure I didn't miss anything:" 377
#
#
# ' C. Now B is in hand, C is clear.\n2. Put down B. Now B'
# 'Let me outline the steps:' 378
#
#
# ' C.\n\n2. Put down A.\n\n3. Unstack C from B.\n\n4. Put down'
# 'So, the steps would be:' 379
#
#
# ' D\n2. Put down A\n3. Pick up D\n4. Stack D on A'
# 'So the plan is:' 380
#
#
# ' A: D is in hand, A is clear on table.\n2. Put down D: D'
# 'Let me think about the steps.' 381
#
#
# ' on top of Block A. (Since B is clear and on top of A, this is allowed'
# 'Let me try to write the plan step by step, making sure each action is valid.' 382
#
#
# ' C.\n\n2. Put down A.\n\n3. Pick up C.\n\n4. Stack C on D'
# 'So, the plan would be:' 383
#
#
# ' D\n2. Put down C\n3. Unstack D from A\n4. Stack D'
# 'Let me recount:' 384
#
#
# ' Block B. Now, C is in hand, B is clear.\n2. Put down Block C'
# 'So let me outline the steps:' 385
#
#
# ' B.\n2. Put down A.\n3. Pick up B.\n4. Stack B on A'
# 'Let me think about the steps.' 386
#
#
# ' C. Now, A is on the table, C is on B, which is on D.\n'
# 'Let me outline the steps:' 387
#
#
# ' A.\n\n2. Put down D.\n\n3. Unstack A from B.\n\n4. Put down'
# 'So, the correct plan is:' 388
#
#
# ' A. (Now, A is on table, D is in hand)\n2. Put down D'
# 'Let me outline the steps:' 389
#
#
# ' D: valid because C is on D, and C is clear.\n\n2. Put down C:'
# 'Yes, that works. So the plan would be:' 390
#
#
# ' B\n\n2. Put down D\n\n3. Unstack C from A\n\n4. Stack C'
# 'So, the plan would be:' 391
#
#
# " A. Hand is empty, D is clear (since it's on top of A). So,"
# 'Let me go through the steps again:' 392
#
#
# '2. Stack C on D\n3. Unstack A from B\n4. Stack A on'
# 'Therefore, the correct plan is:' 393
#
#
# ' B\n2. Put down C\n3. Unstack B from D\n4. Put down'
# 'So the plan would be:' 394
#
#
# ' D.\n2. Put down A.\n3. Pick up D.\n4. Stack D on B'
# 'So the plan would be:' 395
#
#
# ' C.\n\n2. Put down D.\n\n3. Unstack C from A.\n\n4. Put down'
# 'So the plan would be:' 396
#
#
# ' D.\n2. Put down C.\n3. Pick up D.\n4. Stack D on B'
# 'Let me outline the steps:' 397
#
#
# ' B. Now, C is in hand, B is clear.\n\n2. Put down C on the'
# 'Let me outline the steps:' 398
#
#
# ' D. (A is in hand, D is clear)\n2. Put down A on table.'
# 'Let me outline the plan again:' 399
#
#
# ' A, put down B.\n2. Unstack A from D, put down A.\n3.'
# 'So, the plan would be:' 400
#
#
# ' D. (A in hand)\n2. Put down A. (A on table)\n3.'
# 'So the steps would be:' 401
#
#
# ' C. (D is now in hand, C is on B.)\n\n2. Stack D on A'
# 'Let me go through the steps again:' 402
#
#
# ' A.\n\n2. Put down B.\n\n3. Unstack A from D.\n\n4. Put down'
# 'So the plan is:' 403
#
#
# ' Block D.\n\n2. Put down Block C.\n\n3. Pick up Block A.\n\n4. Stack'
# 'So the plan would be:' 404
#
#
# ' B. D in hand, B clear.\n\n2. Put down D on table.\n\n3. Un'
# 'Let me outline this plan:' 406
#
#
# ' B. Since A is clear, I can unstack it. After this, A is in hand'
# 'Let me think about the steps.' 407
#
#
# ' top of D. Now, the stack is B-D-C.\n\n9. Finally, I need to'
# 'Let me think about the steps:' 408
#
#
# ' A. Hand is empty, D is clear, so I can unstack D. Now, I'
# 'Let me go through each step:' 409
#
#
# ' C.\n\n2. Put down B.\n\n3. Unstack C from D.\n\n4. Put down'
# 'So the plan would be:' 410
#
#
# ' B. (D in hand)\n2. Put down D. (D on table)\n3.'
# 'So, to recap, the steps are:' 411
#
#
# ' C.\n2. Put down D.\n3. Pick up B.\n4. Stack B on C'
# 'Let me outline the steps:' 412
#
#
# ' A.\n2. Stack C on B.\n3. Pick up A.\n4. Stack A on'
# 'So the plan is:' 413
#
#
# ' A. Now, C is in my hand, and A is on the table, clear. \n'
# 'Let me think step by step.' 414
#
#
# ' B. Now, C is on the table, B is on A, A is on the table'
# 'Let me go through the plan again.' 415
#
#
# ' C. Now, A is in hand, C is on B.\n\n2. Put down A on'
# 'So, the steps could be:' 416
#
#
# ' B\n2. Put down A\n3. Unstack B from D\n4. Put down'
# 'So, the plan would be:' 418
#
#
# ' A.\n\n2. Put down C.\n\n3. Unstack A from B.\n\n4. Put down'
# 'So the plan would be:' 419
#
#
# ' D: Now, C is in hand, D is on top of B, which is on top'
# 'Let me go through each action carefully.' 420
#
#
# ' A. Hand holds C.\n2. Put down C. C is on table.\n3. Now'
# 'Alternative approach:' 421
#
#
# ' B.\n\n2. Put down D.\n\n3. Unstack B from A.\n\n4. Put down'
# 'So the plan would be:' 422
#
#
# ' D. Now, C is in hand, D is on table, clear.\n2. Put down'
# 'Let me try:' 423
#
#
# '2. Stack A on B.\n\n3. Pick up D.\n\n4. Stack D on A.\n\n'
# 'So, the plan is:' 424
#
#
# ' D.\n2. Put down B.\n3. Unstack D from C.\n4. Put down'
# 'So the plan would be:' 425
#
#
# ' B. Now, D is on the table, B is clear.\n2. Put down D.\n'
# 'Let me try again:' 426
#
#
# ' D. Now, C is in hand, D is on B.\n2. Put down C on'
# 'So let me try this approach:' 427
#
#
# ' D.\n2. Put down C.\n3. Unstack D from B.\n4. Put down'
# 'So, the plan would be:' 428
#
#
# ' A. (C is now in hand)\n2. Put down C. (C is on table'
# 'Let me go through the plan again.' 429
#
#
# ' B.\n\n2. Put down A.\n\n3. Pick up D.\n\n4. Stack D on C'
# 'So, the plan would be:' 430
#
#
# ' A.\n2. Put down B.\n3. Unstack A from D.\n4. Put down'
# 'Let me go through each action:' 431
#
#
# ' D. Now, B is in hand, D is on the table.\n2. Put down B'
# "Let me go through this step by step to make sure I don't miss anything." 432
#
#
# ' C. Now, B is in hand, C is on table, clear.\n\n2. Stack B'
# 'Let me try to outline the steps:' 433
#
#
# ' C\n2. Put down B\n3. Unstack C from D\n4. Put down'
# 'So, the plan would be:' 434
#
#
# ' B. Now, C is in hand, B is clear.\n2. Put down C on the'
# 'Wait, but let me outline the steps properly:' 435
#
#
# ' D.\n\n2. Put down B.\n\n3. Unstack D from C.\n\n4. Put down'
# 'So the steps would be:' 436
#
#
# ' C.\n2. Put down B.\n3. Unstack C from A.\n4. Put down'
# 'Let me recount the steps:' 437
#
#
# ' D\n2. Put down A\n3. Unstack D from C\n4. Put down'
# 'So the plan would be:' 438
#
#
# ' C.\n\n2. Put down D.\n\n3. Unstack C from B.\n\n4. Put down'
# 'So, the plan would be:' 439
#
#
# ' B. Now, C is in hand, B is on A.\n2. Put down C on'
# 'Let me go through the steps again:' 440
#
#
# ' D.\n\nAfter that, B is in my hand, and D is on the table. Now,'
# 'Let me write that down:' 441
#
#
# ' B (A is now on table)\n2. Put down A (hand empty)\n3. Un'
# 'Let me outline it again:' 443
#
#
# ' C. (D in hand, C clear)\n2. Put down D. (D on table'
# 'Let me try another approach.' 444
#
#
# ' B. Now, D is in hand, B is clear.\n\n2. Put down D. Now'
# 'Let me go through each step again.' 445
#
#
# ' A\n2. Put down C\n3. Unstack A from B\n4. Put down'
# 'Let me recount:' 446
#
#
# ' C\n2. Put down D\n3. Unstack C from A\n4. Put down'
# 'So the plan would be:' 447
#
#
# ' on top of Block A. Now, B is on the table, A is on the table.\n\n'
# 'Let me write the plan step by step.' 448
#
#
# ' A.\n2. Stack D on B.\n3. Unstack A from C.\n4. Stack'
# 'So the plan would be:' 449
#
#
# ' B\n2. Stack C on D\n3. Pick up B\n4. Stack B on'
# 'So, the plan is:' 451
#
#
# " Block A. Since C is clear, I can do this. Now I'm holding C.\n\n2"
# 'So step by step:' 452
#
#
# ' B: So, action is unstack A from B. After this, A is in hand,'
# 'Let me try to list each action step by step:' 453
#
#
# ' A.\n2. Put down C.\n3. Pick up A.\n4. Stack A on D'
# 'Alternatively, after moving C to the table and A to D, maybe I can then move C on top of B, then move D on top of C, and then move A on top of D. Let me see:' 454
#
#
# ' C. Now, holding B.\n\n2. Stack B on D. Now, D has B on'
# 'So, revised plan:' 455
#
#
# ' D\n2. Put down B\n3. Unstack D from C\n4. Put down'
# "So, in the problem I'm solving, I think the plan would be:" 456
#
#
# ' A (hand holds D)\n2. Put down D on the table\n3. Unstack A'
# 'Let me list the steps again:' 457
#
#
# ' D. (Now, A is in hand, D is clear)\n2. Stack A on B'
# 'Let me write down the steps clearly:' 458
#
#
# ' D, put it down on the table.\n2. Then, pick up B, stack it on'
# 'So the order would be:' 460
#
#
# ' A. Hand holds C.\n\n8. Put down C on table.\n\n9. Unstack A from'
# 'Yes, all steps seem valid. So the plan would be:' 461
#
#
# ' C. (A is now in hand)\n2. Put down A on table.\n3. Un'
# 'So, the plan is:' 462
#
#
# ' D.\n2. Put down C.\n3. Unstack D from A.\n4. Put down'
# 'So the steps would be:' 464
#
#
# ' Hand is empty, A is clear. Correct.\n\n2. Put down A: Hand was holding A'
# 'Let me go through each action and check the restrictions.' 465
#
#
# ' A. Now, C is in hand, A is on D.\n2. Put down C.'
# 'Let me try to outline the steps.' 467
#
#
# ' D.\n2. Put down A.\n3. Unstack D from B.\n4. Put down'
# 'So, the plan would be:' 468
#
#
# ' B (since C is clear)\n2. Put down C\n3. Unstack B from D'
# 'Wait, perhaps the correct sequence is:' 469
#
#
# ' A. Now, C is on the table, A is on B, B is on D,'
# 'Let me outline the steps:' 470
#
#
# ' C\n2. Put down B\n3. Pick up D\n4. Stack D on B'
# 'So the plan would be:' 471
#
#
# ' D.\n2. Put down A.\n3. Unstack D from C.\n4. Put down'
# "Let me recap the steps to make sure I didn't miss anything:" 472
#
#
# ' D: Valid because B is on top of D, and B is clear.\n\n2. Put down'
# "So let's start building the stack." 473
#
#
# ' C. Since B is on top of C and B is clear, I can do this. Now'
# 'So, the steps I need to take are:' 474
#
#
# '2. Stack D on A. Now, D is on A, and A is on the table'
# 'Let me outline the steps:' 475
#
#
# ' C. (D is now in hand, C on B on A on table)\n2. Put'
# 'Let me go through the steps again.' 476
#
#
# ' B. Since C is clear, I can do that. Then put down C.\n\n2. Now'
# "Wait, but let me make sure I didn't miss any steps. Let me go through each action:" 477
#
#
# '2. Stack C on B.\n3. Pick up D.\n4. Stack D on C.\n'
# 'Yes, that seems to work. So the plan would be:' 478
#
#
# ' A.\n2. Put down B.\n3. Pick up A.\n4. Stack A on B'
# 'Let me list the steps:' 480
#
#
# ". But where? I can't stack it yet because I need to build the structure. Maybe just"
# 'But let me go through the plan again.' 481
#
#
# ' B.\n\n2. Put down A.\n\n3. Unstack D from C.\n\n4. Put down'
# 'So the steps are:' 482
#
#
# ' B. Since D is on top of B, and D is clear, I can unstack it'
# 'Let me outline the steps:' 483
#
#
# '2. Stack A on C.\n3. Pick up D.\n4. Stack D on A.\n'
# 'So the plan would be:' 484
#
#
# ' B.\n2. Put down D.\n3. Unstack B from C.\n4. Put down'
# 'So, the plan would be:' 485
#
#
# ' C\n2. Put down D\n3. Unstack C from B\n4. Put down'
# 'So the plan would be:' 486
#
#
# ' C.\n2. Put down A.\n3. Unstack C from B.\n4. Put down'
# 'Let me list the steps:' 487
#
#
# ' A.\n2. Unstack A from C.\n3. Stack A on D.\n4. Stack'
# 'So, the plan is:' 490
#
#
# ' C: allowed because B is on top of C and clear.\n2. Put down B: allowed'
# 'So I need to first stack B on D.' 491
#
#
# ' A: Valid because C is clear and on top of A.\n2. Put down C: Valid'
# 'Let me go through each step:' 493
#
#
# ' D.\n\n2. Put down C.\n\n3. Unstack D from A.\n\n4. Put down'
# 'So, to recap:' 494
#
#
# ' D. (A is now in hand)\n2. Put down A. (A is on table'
# 'Let me go through the plan again.' 495
#
#
# ' D → C in hand.\n\n2. Stack C on B → Now, B has C.\n\n3'
# 'So the plan would be:' 496
#
#
# " B. Now, I'm holding A, B is on the table, clear.\n\nBut wait,"
# 'So, step 1: Unstack Block A from Block B.' 498
#
#
# ' D. Now, A is on the table, D is on the table.\n2. Unstack'
# 'Let me go through each step again.' 499
#
#
# ' C. Now, A is in hand, C is clear.\n2. Put down A. Now'
# 'Let me outline the steps:' 500
#
#
# ' A: Yes, C was on A, and C was clear. After unstacking, I'
# 'Let me think about the steps needed.' 501
#
#
# ' B: Valid because A is on top of B and is clear.\n2. Put down A:'
# 'Let me outline the steps:' 502
#
#
# ' D. Now, B is in hand, D is on the table, clear.\n2. Put'
# 'Let me outline the steps:' 503
#
#
# ' A.\n\n2. Put down C.\n\n3. Unstack A from B.\n\n4. Put down'
# 'So the plan would be:' 504
#
#
# ' B\n2. Put down C\n3. Unstack D from A\n4. Put down'
# 'Let me recount the steps:' 505
#
#
# ' B. Hand is empty, D is clear. So yes, possible. Now, D is in'
# 'Let me go through each action:' 506
#
#
# ' A.\n2. Put down C.\n3. Unstack A from B.\n4. Put down'
# 'So the plan would be:' 507
#
#
# ' top of Block A. Now, Block B is on top of Block A, which is on the'
# '5. Pick up Block B.' 508
#
#
# ' C. Now, B is in hand, C is on A, A is on D.\n\n2'
# 'Let me go through the plan step by step.' 509
#
#
# ' A.\n2. Put down C.\n3. Unstack A from D.\n4. Put down'
# 'So the plan would be:' 510
#
#
# ' A\n2. Put down C\n3. Unstack A from B\n4. Put down'
# 'So the plan would be:' 511
#
#
# ' B\n2. Put down D\n3. Unstack B from A\n4. Stack B'
# 'So, the plan is:' 512
#
#
# ' C.\n2. Put down A.\n3. Unstack B from D.\n4. Put down'
# 'So the plan would be:' 513
#
#
# ' C.\n\n2. Put down D.\n\n3. Unstack C from A.\n\n4. Put down'
# 'Let me recount:' 514
#
#
# ' B. Now, C is on table, B on D.\n\n2. Put down C. ('
# 'Let me recount:' 516
#
#
# ' D. Now, holding C.\n2. Put down C. Now, C is on table,'
# 'So let me adjust the plan accordingly.' 517
#
#
# ' B. Now, A is in hand, B is on the table, clear. C and D'
# 'Let me plan the steps.' 518
#
#
# ' stack it on D. Now, C is on D, and D is on the table. \n\n'
# 'Let me plan:' 519
#
#
# ' C: Hand is empty, B is clear, so allowed. Now, B is in hand,'
# 'Let me go through each step:' 520
#
#
# ' A is clear, hand is empty. So, allowed.\n2. Put down A: Now,'
# 'Let me go through each step:' 521
#
#
# ' C. (Holding A, C clear)\n2. Put down A on table.\n3.'
# 'To achieve this, I need to:' 522
#
#
# ' C. Now, B is in hand, C is on D, D is on table. A'
# 'Let me try to outline the steps:' 524
#
#
# ' D.\n\n2. Put down A.\n\n3. Unstack D from C.\n\n4. Put down'
# 'Let me recount the steps:' 525
#
#
# " Block B. Now, I'm holding C, and B is clear on the table.\n\nNext,"
# 'Let me think about the steps.' 526
#
#
# ' A.\n2. Put down C.\n3. Pick up B.\n4. Stack B on A'
# 'So, the plan would be:' 527
#
#
# ' C\n2. Put down B\n3. Unstack C from A\n4. Put down'
# 'So the plan would be:' 528
#
#
# ' B. Now, C is in my hand, and B is clear on top of D. But'
# 'Let me think about the steps I need to take.' 529
#
#
# ' C.\n2. Put down B.\n3. Unstack C from D.\n4. Put down'
# 'So, the plan is:' 530
#
#
# ' A: Now B is in hand, stack is C -> D -> A.\n2. Put down'
# 'Let me go through each action:' 531
#
#
# ' B.\n2. Put down A.\n3. Unstack B from C.\n4. Put down'
# 'I think the most efficient way is:' 532
#
#
# ' Now, D is in my hand.\n\n8. Stack D on A. Now, D is on'
# 'Let me plan the steps to stack them correctly.' 533
#
#
# " D. Now, I'm holding C. D is now on the table, clear.\n\n2."
# 'Let me think about the sequence.' 535
#
#
# ' B.\n\n2. Put down D.\n\n3. Pick up A.\n\n4. Stack A on D'
# 'So the plan would be:' 536
#
#
# ' D. (Now, B is in hand, D is on table)\n2. Put down B'
# 'Let me outline the steps:' 537
#
#
# ' Block A\n2. Put down Block B\n3. Unstack Block A from Block C\n'
# 'So the plan is:' 538
#
#
# ' C. Now, B is in hand, and C is on top of A.\n\n2. Put'
# 'Let me try this approach:' 539
#
#
# " A. Now, I'm holding B, and A is clear.\n2. Put down B on"
# 'So the steps might be:' 540
#
#
# ' C\n2. Put down D\n3. Pick up C\n4. Stack C on B'
# 'So, the plan is:' 541
#
#
# ' B. (A is in hand, B is clear)\n2. Put down A. (A'
# "But let me make sure I didn't miss any steps. Let me go through the steps again:" 542
#
#
# ' A.\n2. Put down C.\n3. Unstack A from D.\n4. Put down'
# 'So, the plan would be:' 543
#
#
# ' C.\n2. Put down D.\n3. Unstack C from A.\n4. Put down'
# 'So the plan would be:' 544
#
#
# ' Block D.\n\n2. Put down Block B.\n\n3. Unstack Block D from Block A.\n\n'
# 'So the plan would be:' 545
#
#
# ' A: Valid, C is on A, clear. Now, C in hand.\n\n2. Put'
# 'Let me try again.' 546
#
#
# ...
#
#
# ' D. Now, A is on the table, D is on C, which is on the table'
# 'Let me outline the steps:' 1319
#
#
# ' D. Now, A is in hand, D is on B, B is on table, C'
# 'Let me try:' 1321
#
#
# ' D.\n\n2. Put down C.\n\n3. Pick up A.\n\n4. Stack A on B'
# 'So the steps would be:' 1322
#
#
# ' B. Now, D is in hand, B is on table, clear.\n2. Put down'
# 'Let me go through the plan again.' 1323
#
#
# ' A.\n2. Put down B.\n3. Unstack A from D.\n4. Put down'
# 'So the corrected plan would be:' 1324
#
#
# ' D. Now, C is in hand, D is on B, and B is on the table'
# "Let me outline the steps again to make sure I don't miss anything:" 1325
#
#
# ' A: C is clear, so yes.\n\n2. Put down C: Hand was holding C,'
# 'Let me go through each step and check the conditions.' 1326
#
#
# ' B. Now, D is on the table, B is on top of A, hand is empty'
# 'Let me outline the steps:' 1327
#
#
# " Block A. Now, I'm holding C, and A is on the table.\n2. Put"
# 'Let me outline the steps:' 1328
#
#
# ' A. Now, D is in hand, A is on the table, clear.\n2. Put'
# 'Let me outline the steps:' 1329
#
#
# ' A. (B in hand, A on table)\n2. Put down B. (B on'
# 'Let me try:' 1330
#
#
# ' A. Now, C is in hand, A is on table.\n2. Put down C on'
# 'Let me outline the steps:' 1331
#
#
# ' B: C is clear, so yes. Hand becomes empty after unstacking, but wait,'
# 'So let me outline the steps:' 1333
#
#
# ' B\n2. Put down C\n3. Unstack B from A\n4. Put down'
# 'So the plan would be:' 1334
#
#
# ' B: Now, C is in hand, B is clear.\n2. Put down C: C'
# "Let me go through each step again to make sure I didn't make a mistake." 1335
#
#
# ' B\n2. Put down D\n3. Unstack B from C\n4. Put down'
# 'Let me recount:' 1336
#
#
# ' D. Now, holding B.\n2. Put down B. Now, B is on table.\n'
# 'So let me adjust the plan accordingly.' 1337
#
#
# ' D, put down.\n\n2. Unstack D from A, put down.\n\n3. Pick up'
# 'So, the plan would be:' 1338
#
#
# ' C. A on table, stack D -> B -> C.\n\n2. Unstack C from B'
# 'Let me correct the steps:' 1339
#
#
# ' A.\n2. Put down D on table.\n3. Unstack A from B.\n4.'
# 'So, summarizing the steps:' 1340
#
#
# ' D. Now, C is in hand, D is on the table, clear.\n2. Stack'
# 'Let me outline the steps I think I need to take:' 1341
#
#
# ' A. Now D is on the table, A is on top of B, which is on C'
# 'So step by step:' 1342
#
#
# ' D. Now, C is in hand, D is on B, B on table.\n\n2.'
# 'Let me go through the plan again.' 1343
#
#
# ' A\n2. Put down B\n3. Pick up A\n4. Stack A on B'
# 'So, the plan would be:' 1344
#
#
# ' B. Now, D in hand, B on table, C on table, A on C.\n\n'
# "So, let's try:" 1347
#
#
# ' C.\n\n2. Put down A.\n\n3. Unstack C from D.\n\n4. Stack C'
# 'So, the plan would be:' 1348
#
#
# ' A. (C is clear, so I can unstack it.)\n\n2. Put down C.\n\n'
# 'So, the steps would be:' 1349
#
#
# '2. Stack A on B. Now, B has A on top, so B is no longer'
# 'Let me outline the steps:' 1350
#
#
# ' D\n2. Stack A on C\n3. Unstack D from B\n4. Un'
# 'So the plan is:' 1351
#
#
# ' Now, A is on the table, D is on C, which is on B, and hand'
# 'Let me try that.' 1352
#
#
# "since it's on the table and clear).\n2. Stack D on B.\n\nBut wait, is"
# 'So, the steps would be:' 1353
#
#
# ' Block A. Now, B is in hand, A is on D, D is on table,'
# 'So, step by step:' 1354
#
#
# ' B. Now, A is in hand, B is on table, clear.\n2. Put down'
# 'Let me go through each action:' 1355
#
#
# ' C\n2. Put down B\n3. Unstack C from A\n4. Put down'
# 'So the plan is:' 1357
#
#
# ' C. Now, A is on the table, C is on top of B.\n2. Un'
# 'Let me try that:' 1358
#
#
# ' A. B is held, A on C, C on D, D on table.\n2.'
# 'So the steps would be:' 1359
#
#
# ' C. Now, B is in hand, C is on the table, clear.\n2. Put'
# 'So, let me outline the steps:' 1361
#
#
# ' B\n2. Put down D\n3. Unstack B from A\n4. Put down'
# 'So, the plan is:' 1362
#
#
# ' B: Now, C is in hand, B is on A, A on D.\n\n2.'
# 'So, the plan would be:' 1363
#
#
# ' B\n2. Put down D\n3. Unstack B from A\n4. Put down'
# 'So, the plan would be:' 1364
#
#
# ' D: possible because B is clear and on top of D.\n2. Put down B: hand'
# 'Let me go step by step.' 1365
#
#
# ' Block C.\n\n2. Put down Block A.\n\n3. Unstack Block C from Block B.\n\n'
# 'So, the plan would be:' 1367
#
#
# ' Block C\n2. Put down Block A\n3. Pick up Block D\n4. Stack'
# 'So, in my case, the plan would be:' 1368
#
#
# ' A. Now, A is no longer clear, B is on top of A. Hand is empty'
# 'Let me go through each step:' 1369
#
#
# ' A, put down D.\n\n2. Unstack A from C, put down A.\n\n3.'
# 'Let me list them:' 1370
#
#
# ' B. Now, A is in hand, B is on the table, clear.\n2. Put'
# 'Let me outline the steps I might need:' 1371
#
#
# ' C\n2. stack B on A\n3. pick up D\n4. stack D on'
# 'So, the plan would be:' 1372
#
#
# ' D: possible because C is on D and clear.\n2. Put down C: yes, hand'
# 'So, the plan would be:' 1373
#
#
# ' D\n2. Put down A\n3. Unstack D from B\n4. Put down'
# 'Let me write it out clearly:' 1374
#
#
# ' C. Now, A is on the table, C is on B, which is on D.\n\n'
# 'So the steps would be:' 1375
#
#
# ' B\n2. Put down A\n3. Unstack B from C\n4. Put down'
# 'So, the plan would be:' 1376
#
#
# '2. Put down A on table\n3. Unstack D from B\n4. Stack D'
# 'Let me outline the steps clearly.' 1377
#
#
# ' B. (A is now in hand, B is clear)\n2. Put down A. ('
# 'So, the steps would be:' 1378
#
#
# ' C.\n\n2. Put down A.\n\n3. Unstack C from D.\n\n4. Put down'
# 'So the correct plan would be:' 1380
#
#
# ' C. Now, B is in hand, C is clear.\n\n2. Put down B. Now'
# 'So the steps I took were:' 1381
#
#
# ' D. Now holding A.\n2. Put down A. Hand empty.\n3. Unstack D'
# 'So the steps would be:' 1382
#
#
# ' D\n2. Put down A\n3. Unstack D from B\n4. Put down'
# 'Let me try:' 1383
#
#
# ' B\n2. Put down D\n3. Unstack B from C\n4. Stack B'
# 'So, the plan would be:' 1384
#
#
# ' C\n2. Put down B\n3. Unstack C from A\n4. Put down'
# 'Let me try:' 1385
#
#
# ' D. But wait, can I do that? Because B is on D, and B is clear'
# 'Let me try that.' 1386
#
#
# ' A: Valid because B is clear and on top of A.\n\n2. Put down B: Valid'
# 'Let me go through the steps again:' 1387
#
#
# ' D: C is clear, so allowed.\n2. Put down C: Hand was holding C,'
# 'So the plan would be:' 1388
#
#
# ' B (since A is on top of B). Wait, no, A is on top of B'
# 'So, let me outline the steps properly:' 1389
#
#
# ' C\n2. Put down B\n3. Unstack C from D\n4. Put down'
# 'So the plan would be:' 1390
#
#
# ' D.\n\n2. Stack A on B.\n\n3. Unstack D from C.\n\n4. Stack'
# "But let me make sure I didn't miss any steps. Let me list them:" 1391
#
#
# ' A.\n\n2. Put down C.\n\n3. Unstack A from D.\n\n4. Put down'
# 'So, the final plan is:' 1392
#
#
# ' B.\n2. Put down C.\n3. Unstack B from A.\n4. Put down'
# 'Let me go through the steps again:' 1393
#
#
# ' C\n\n2. put down A\n\n3. unstack C from D\n\n4. put down'
# 'Let me write it out step by step:' 1394
#
#
# ' A. Hand holds B, A is on table.\n\n2. Put down B. B is on'
# 'Let me try again:' 1395
#
#
# ' C. Now, D is in hand, C is on the table, clear.\n\n2. Put'
# 'Let me outline the steps:' 1396
#
#
# ' A. Hand holds C.\n2. Put down C on table.\n3. Pick up A.'
# 'Let me try:' 1397
#
#
# ' C.\n\n2. Put down D.\n\n3. Pick up A.\n\n4. Stack A on D'
# 'So the plan would be:' 1398
#
#
# ' B.\n\n2. Put down C.\n\n3. Pick up A.\n\n4. Stack A on D'
# 'So the plan would be:' 1399
#
#
# ' C\n2. Put down D\n3. Unstack C from B\n4. Put down'
# 'So the plan is:' 1400
#
#
# ' D.\n\n2. Stack B on C.\n\n3. Unstack D from A.\n\n4. Stack'
# 'So the plan would be:' 1401
#
#
# ' B. Now, C is on the table, B is clear.\n2. Put down C.'
# 'Wait, let me outline the steps:' 1402
#
#
# ' D. (B in hand, D on A, C on table)\n2. Put down B'
# 'Let me try to outline the steps again:' 1403
#
#
# ' C. Now, A is on the table, C is on D, but wait, no,'
# 'Let me go through the plan again.' 1404
#
#
# ' C. Now, A is in hand, C is on B, B is on table, D'
# 'Let me outline the steps:' 1405
#
#
# '5. Stack D on top of C.\n\nNow, the state is:\n\n- Table has A and'
# 'But let me check the initial conditions again.' 1406
#
#
# ' A\n2. Stack B on D\n3. Unstack B from D\n4. Stack'
# 'So the plan would be:' 1407
#
#
# ' D\n2. Put down C\n3. Unstack D from A\n4. Put down'
# 'So the plan would be:' 1409
#
#
# ' C\n2. Put down D\n3. Pick up A\n4. Stack A on C'
# 'So the steps are:' 1410
#
#
# ' D\n2. Put down A\n3. Unstack D from C\n4. Put down'
# 'Yes, all steps are valid. So the plan would be:' 1411
#
#
# ' C. Now, A is in hand, C is on the table, clear.\n2. Stack'
# 'Let me outline the steps:' 1412
#
#
# ' D: Since C was on D, and C was clear, I can unstack it. Hand'
# 'Let me think step by step.' 1413
#
#
# ' C (since D is clear).\n2. Put down D on the table.\n3. Now,'
# "So let's outline the steps:" 1414
#
#
# ' C. Since A is on C, and A is clear, I can unstack it. After'
# 'So, step by step:' 1416
#
#
# ' B. Now, C is on the table, B is on top of D, which is on'
# 'Let me go through each step carefully.' 1417
#
#
# ' B. Now, D is on table, B is clear.\n2. Pick up A.\n3'
# 'So, the steps I need to take are:' 1418
#
#
# ' Block B. Now, Block C is on the table, and Block B is clear.\n2.'
# 'Let me outline the steps:' 1419
#
#
# ' C: Now, D is in hand, C is clear.\n\n2. put down D: D'
# 'So, the plan is:' 1420
#
#
# ' B: valid because D is on top of B and clear.\n2. Put down D: valid'
# 'Let me try to write the plan step by step, making sure each action is valid.' 1421
#
#
# ' B. Now, C is in my hand, and B is on top of D, which is'
# 'Wait, but C is on top of B, so I can unstack C first. Let me try that.' 1423
#
#
# ' C. Now, B is in hand, C is clear on the table.\n\n2. Put down'
# 'Wait, but let me outline the steps properly.' 1424
#
#
# ' Block A. Since Block C is clear, I can do this. After this, Block C is'
# 'Let me outline the steps:' 1425
#
#
# ' D.\n2. Put down C.\n3. Unstack D from B.\n4. Put down'
# 'So the steps are:' 1426
#
#
# ' D: valid because A is on top of D and clear.\n\n2. Put down A: valid'
# 'So the plan would be:' 1427
#
#
# ' B.\n2. Put down C.\n3. Unstack B from A.\n4. Put down'
# 'Let me go through each action:' 1428
#
#
# ' C. Now, D is on table, C is on B. Hand is empty.\n\n2.'
# 'Let me think about the steps:' 1429
#
#
# ' B\n2. Put down D\n3. Unstack B from C\n4. Put down'
# 'So, the plan is:' 1430
#
#
# '2. Stack A on D. Now, D has A on top, so D is no longer'
# 'Let me outline the steps:' 1431
#
#
# ' B\n2. Put down D\n3. Unstack B from C\n4. Unstack'
# 'So the plan is:' 1432
#
#
# ' C\n2. Put down D\n3. Unstack C from B\n4. Stack C'
# 'So the steps would be:' 1433
#
#
# ' A. Now, D is in hand, A is on table, clear.\n2. Put down'
# 'So let me outline the steps:' 1435
#
#
# 'hand has A)\n2. Put down A (A is on table)\n3. Now, D'
# 'So, step by step:' 1436
#
#
# '2. Stack A on B\n3. Pick up C\n4. Stack C on A\n\n'
# 'Let me write down the plan:' 1437
#
#
# ' C.\n\n2. Put down A.\n\n3. Unstack C from D.\n\n4. Put down'
# 'So, the steps would be:' 1438
#
#
# ' A. Now, D is in hand, A is on table, clear. \n2. Put'
# 'Let me think about the steps.' 1439
#
#
# ' A\n2. Put down C\n3. Unstack A from D\n4. Put down'
# 'So the plan is:' 1440
#
#
# ' D. Now, C is in my hand, D is on the table, and A and B'
# 'Let me outline the steps I think I need to take:' 1441
#
#
# "2. Stack C on top of A.\n\nBut wait, let me make sure I'm not missing"
# 'So the steps would be:' 1442
#
#
# ' B. (D in hand, B clear)\n2. Stack D on C. (C has'
# 'Alternatively, perhaps I can do it in fewer steps. Let me try:' 1443
#
#
# ' A\n2. Put down B\n3. Pick up C\n4. Stack C on B'
# 'So, the steps would be:' 1444
#
#
# ' A. Now, D is in hand, A is clear.\n2. Put down D. Now'
# 'Let me go through each action:' 1445
#
#
# ' B.\n\n2. Put down C.\n\n3. Unstack B from A.\n\n4. Put down'
# 'So, the initial plan was:' 1446
#
#
# ' A.\n2. Put down B.\n3. Unstack A from D.\n4. Put down'
# 'So the steps would be:' 1447
#
#
# " Block B. Since C is clear, I can do this. After this, I'm holding C"
# 'Let me outline the steps I think I need:' 1448
#
#
# ' B: valid because C is on top of B and clear.\n2. Put down C: valid'
# 'First, I need to get C off of B.' 1449
#
#
# ' B.\n\n2. Put down A.\n\n3. Unstack B from D.\n\n4. Put down'
# 'So perhaps the initial approach is correct: unstack A, B, D, then C, then rebuild the stack.' 1450
#
#
# ' C.\n\n2. Put down B.\n\n3. Unstack C from D.\n\n4. Put down'
# 'So the plan would be:' 1452
#
#
# ' Block B. Now, Block C is in hand, Block B is on the table, clear.\n'
# 'Let me outline the steps:' 1453
#
#
# ' A.\n\n2. Put down C.\n\n3. Pick up C.\n\n4. Stack C on B'
# 'So the plan would be:' 1454
#
#
# ' D. Now, B is on the table, D is on A, hand is empty.\n2'
# 'Let me outline the steps:' 1456
#
#
# ' C. Now, D is in hand, C is on the table.\n2. Stack D on'
# 'So let me outline the steps:' 1457
#
#
# ' A.\n\n2. Put down D.\n\n3. Unstack A from B.\n\n4. Put down'
# 'So the steps would be:' 1458
#
#
# ' B: valid because C is on top of B and clear.\n2. Put down C: valid'
# 'Let me go through each step:' 1459
#
#
# ' on top of Block A\n2. Put down Block B\n3. Unstack Block A from'
# 'Let me write them out clearly:' 1460
#
#
# ' D. Now, B is in hand, D is on the table, clear again.\n\n2.'
# 'First, I need to move B from D to the table.' 1461
#
#
# ' C.\n2. Stack D on B.\n3. Unstack C from A.\n4. Stack'
# 'So the steps would be:' 1463
#
#
# ' A: Valid because D is on top of A and clear.\n2. Put down D: Valid'
# 'Let me check if all the steps are valid.' 1464
#
#
# ' C. Now, B is in hand, C is on A.\n2. Put down B on'
# "Let me recap the steps to make sure I didn't miss anything:" 1466
#
#
# ' C: Valid because A is on C and clear.\n2. Put down A: Valid because hand'
# 'Let me go through each action:' 1467
#
#
# ' A\n2. Put down D\n3. Unstack A from C\n4. Put down'
# 'So, the plan would be:' 1469
#
#
# ' A.\n2. Put down C.\n3. Unstack D from B.\n4. Put down'
# 'Let me outline the steps:' 1470
#
#
# ' B first, then stack A on C, then stack D on A.\n\nBut to do that,'
# 'So perhaps the correct order is:' 1471
#
#
# ' Now, C is in hand.\n\n8. Stack C on A. Now, A has C on'
# 'Let me try again after step 6 where all blocks are on the table.' 1472
#
#
# ' B.\n\n2. Put down C.\n\n3. Unstack B from A.\n\n4. Put down'
# 'So the plan would be:' 1473
#
#
# ' A.\n2. Stack D on B.\n3. Pick up A.\n4. Stack A on'
# 'So the steps would be:' 1474
#
#
# ' B. Since D is on top of B and is clear, I can do this. After un'
# 'So, the steps I need to take:' 1475
#
#
# " A. Now, I'm holding D, and the stack is C -> B -> A.\n2"
# 'Let me outline the steps:' 1476
#
#
# ' A. Now, C is in hand, A is on the table.\n2. Stack C on'
# 'Let me outline the steps:' 1477
#
#
# ' B\n2. Put down D\n3. Pick up A\n4. Put down A\n'
# 'So, the steps I outlined seem necessary. Let me write them out clearly:' 1478
#
#
# ' D\n2. Put down C\n3. Unstack B from A\n4. Put down'
# 'So, the plan would be:' 1479
#
#
# ' D.\n\n2. Stack A on B.\n\n3. Pick up D.\n\n4. Stack D on'
# 'So, the plan would be:' 1480
#
#
# ' D\n\n2. put down C\n\n3. unstack D from B\n\n4. stack D'
# 'So the plan is:' 1481
#
#
# ' B, put down C.\n\n2. Unstack B from D, put down B.\n\n3.'
# 'So the steps would be:' 1482
#
#
# ' Block A. Now, Block B is in my hand, and Block A is clear.\n\n2.'
# "Let me double-check the steps to make sure I didn't miss anything." 1483
#
#
# ' D.\n\n2. Put down A.\n\n3. Unstack D from C.\n\n4. Put down'
# 'So the plan would be:' 1484
#
#
# ' C\n2. Put down B\n3. Unstack C from A\n4. Put down'
# 'So the plan is:' 1485
#
#
# '2. Stack B on top of A.\n3. Pick up Block C.\n4. Stack C'
# 'So, the steps would be:' 1486
#
#
# ' B: Valid because A is clear and on top of B.\n2. Put down A: Valid'
# 'So, the plan would involve:' 1487
#
#
# ' D\n2. Put down C\n3. Unstack D from B\n4. Put down'
# 'So the plan is:' 1488
#
#
# ' on top of Block A.\n\n2. Put down Block C.\n\n3. Pick up Block A.\n\n'
# 'So, the plan would be:' 1489
#
#
# ' C, put down D.\n2. Unstack C from A, put down C.\n3.'
# 'So the plan would be:' 1490
#
#
# ' B.\n2. Put down C.\n3. Unstack B from A.\n4. Put down'
# 'So the plan would be:' 1491
#
#
# ' Block A. Since C is clear, I can unstack it. After this, C is in'
# 'Let me outline the steps I think I need:' 1493
#
#
# ' C: Valid because B is on top of C and B is clear.\n\n2. Put down B'
# 'Let me go through each step:' 1494
#
#
# ' B. Now, A is in hand, B is on D, D on table, C on'
# 'Let me go through the steps again.' 1495
#
#
# ' C.\n2. Stack D on B.\n3. Pick up A.\n4. Stack A on'
# 'Let me list the steps again:' 1496
#
#
# ' D. Now, A is in hand, D is on table.\n2. Put down A on'
# 'Let me go through each step again.' 1497
#
#
# '2. Stack A on top of C\n\nBut wait, in the initial problem statement, the user'
# 'So the plan is straightforward:' 1498
#
#
# ' D\n2. Put down B\n3. Unstack C from A\n4. Put down'
# 'So, the plan is:' 1499

# %%
]
