# %%
import os

os.chdir("..")

# %%
from huggingface_hub import snapshot_download

# %%
repo_id = "dmitriihook/blocksworld-results"

snapshot_download(
    repo_id=repo_id,
    repo_type="dataset",
    local_dir="multilayer_representations",
    allow_patterns=["**multilayer**"]
)
# Out:
# Fetching 4632 files:   0%|          | 0/4632 [00:00<?, ?it/s]
# (…)lean_domain_%28mystery_2%29_layer_11.png:   0%|          | 0.00/47.4k [00:00<?, ?B/s]
# clean_domain_%28mystery_2%29_layer_0.png:   0%|          | 0.00/49.0k [00:00<?, ?B/s]
# (…)lean_domain_%28mystery_2%29_layer_13.png:   0%|          | 0.00/47.9k [00:00<?, ?B/s]
# (…)lean_domain_%28mystery_2%29_layer_12.png:   0%|          | 0.00/47.4k [00:00<?, ?B/s]
# clean_domain_%28mystery_2%29_layer_1.png:   0%|          | 0.00/46.2k [00:00<?, ?B/s]
# (…)lean_domain_%28mystery_2%29_layer_14.png:   0%|          | 0.00/47.5k [00:00<?, ?B/s]
# (…)lean_domain_%28mystery_2%29_layer_10.png:   0%|          | 0.00/49.8k [00:00<?, ?B/s]
# (…)lean_domain_%28mystery_2%29_layer_15.png:   0%|          | 0.00/47.3k [00:00<?, ?B/s]
# (…)lean_domain_%28mystery_2%29_layer_16.png:   0%|          | 0.00/48.0k [00:00<?, ?B/s]
# (…)lean_domain_%28mystery_2%29_layer_17.png:   0%|          | 0.00/47.7k [00:00<?, ?B/s]
# ...
